# %% [markdown]
# # FNS

# %% [markdown]
# ## en

# %%
def play() -> None:
    '''Start playback of the current track from where the seekbar is positioned.
    This is one of the most common intent used for initiating music playback.
    Commands (First command is mostly the most common): "Play", "Begin", "Start", "Hit it", "Let's roll", "Drop in", "Count it off", "Kick it", "Take it away", "Da capo", "Start again"'''
    print('player.play()')

def pause() -> None:
    '''Pause the currently playing music track. This intent stops playback while maintaining the current position in the track.Second most common command
    Commands (First command is mostly the most common): "Pause", "Stop", "Cut it", "Hold up", "Break", "Hang on", "Freeze", "Time out", "Cut", "Kill it", "Shut it down"'''
    print('player.pause()')

def from_the_top() -> None:
    '''Restart the current track from its beginning without pausing. This command automatically repositions the seekbar to the start of the song. If the track is paused, it positions the seek bar in the beginning, and it triggers the play right after.Return to start of track
    Commands (First command is mostly the most common): "From the top", "Top it", "Start over",  "Run it again", "Let's take it again", "From the start", "Go again", "From the beggining"'''
    print(f'player.seek(0)')

def go_back(seconds: int) -> None:
    '''Rewind the current track by a preset interval. This intent moves the seekbar to an earlier point in the song.Default 10 seconds back
    Commands (First command is mostly the most common): "Go back", "Run that back", "Take it back", "Rewind that", "Let me hear that again", "Bump that back", "One more time on that", "Back up a bit"'''
    print(f'player.seek(currentTime-{seconds})')

def skip_ahead(seconds: int) -> None:
    '''Advance the playback by a specified interval or jump to a later point in the track. This intent moves the seekbar forward within the current song.Default 10 seconds forward
    Commands (First command is mostly the most common): "Skip ahead", "Jump to the next bit", "Fast forward", "Push ahead", "Skip that part"'''
    print(f'player.seek(currentTime+{seconds})')

def slow_down(bpm: int) -> None:
    '''Decrease the playback speed. This command reduces the tempo in BPMs.Default to reduce -10 BPM from the current BPM
    Commands (First command is mostly the most common): "Slow down", "Take it down a notch", "Ease up", "Pull back", "Drag it", "Chill the tempo", "Throw some molasses on it", "Bring it down", "Not so eager"'''
    print(f'audio.setBpm(currentBpm-{bpm})')

def slow_down_a_lot(bpm: int) -> None:
    '''Decrease the playback speed. This command reduces the tempo in BPMs.Default to reduce -20 BPM from the current BPM.
    Commands (First command is mostly the most common): "Slow down a lot", "Way back", "Crawl with it", "Snail's pace", "Take it way down", "Molasses mode", "Sloooooow motion", "Glacial pace", "Tortoise mode"'''
    print(f'audio.setBpm(currentBpm-{bpm})')

def half_speed() -> None:
    '''Decrease the playback speed. This command reduces the tempo in BPMs dramatically to half of the tempo.Set the current bpm by dividing the current bpm by 2
    Commands (First command is mostly the most common): "Half speed", "Cut it in half", "Give me 50", "Halftime feel", "Half-time", "Break it down", "Slow jam it", "Practice tempo"'''
    print(f'audio.setBpm(currentBpm/2)')

def speed_up(bpm: int) -> None:
    '''Increase the playback speed. This intent accelerates the tempo.Default to increase 10 BPM from the current BPM.
    Commands (First command is mostly the most common): "Speed up", "Push it", "Take it up", "Goose it", "More gas", "Pick up the pace", "Double-time feel", "Let's cook", "Give it some juice"'''
    print(f'audio.setBpm(currentBpm+{bpm})')

def normal_speed() -> None:
    '''Reset the tempo to it's original BPM.Reset to original tempo
    Commands (First command is mostly the most common): "Normal speed", "Back to one", "As written", "On the page", "In time", "Real time", "Back to tempo", "At speed", "How it goes"'''
    print(f'audio.setBpm(originalBpm)')

def set_tempo_by_percent(percentage: int) -> None:
    '''Set tempo to specific user speed setting.Specific tempo setting
    Commands (First command is mostly the most common): "Set tempo to specific percentage", "About specific percentage", "Take it to specific percentage", "Dial it to specific percentage", "Clock it at specific percentage"'''
    print(f'audio.setSpeed({percentage})')

def set_tempo_by_bpm(bpm: int) -> None:
    '''Set tempo to specific BPM requested by user.
    Commands (First command is mostly the most common): "Set tempo to specific number", "About specific number", "Take it to specific number", "Dial it to specific number", "Clock it at specific number", "specific number on the dial", "specific number click", "Knock it back to specific number"'''
    print(f'audio.setBpm({bpm})')

def loop_this_section(startTime: int, endTime: int) -> None:
    '''Activate loop on the current section
    Commands (First command is mostly the most common): "Loop this section", "Vamp on this", "Cycle this", "Round and round here", "Lather, rinse, repeat", "Work this bit", "Drill this", "Spin this", "Let it ride"'''
    print(f'player.setLoop({endTime-startTime})')

def go_to_chorus(sectionName: str) -> None:
    '''Seek forward to the nearest chorusNavigate to marked section
    Commands (First command is mostly the most common): "Go to chorus", "Take it to the hook", "Jump to the refrain", "Hit the chorus", "Straight to the hook", "Skip to the money part", "Get to the chorus"'''
    print(f'sections.jumpTo({sectionName})')

def go_to_verse(sectionName: str) -> None:
    '''Seek forward to the nearest verseNavigate to marked section
    Commands (First command is mostly the most common): "Go to verse", "Back to the verse", "Take it to the verse", "Hit the verse", "Jump to the lyrics", "Verse part", "Into the verse"'''
    print(f'sections.jumpTo({sectionName})')

def go_to_solo(sectionName: str) -> None:
    '''Seek forward to the nearest soloNavigate to marked section
    Commands (First command is mostly the most common): "Go to solo", "Hit the solo", "Take it to the lead", "Jump to the jam", "Solo time", "Lead section", "Get to the licks", "Break time"'''
    print(f'sections.jumpTo({sectionName})')

def loop_the_chorus(sectionName: str) -> None:
    '''Loop marked section
    Commands (First command is mostly the most common): "Loop the chorus", "Cycle the hook", "Round on the refrain", "Vamp on the chorus", "Work the hook", "Drill the chorus", "Hook on repeat", "Circle the chorus"'''
    print(f'sections.loop({sectionName})')

def loop_the_verse(sectionName: str) -> None:
    '''Loop marked section
    Commands (First command is mostly the most common): "Loop the verse", "Cycle the verse", "Round on the verse", "Vamp on the verse", "Woodshed the verse", "Drill the verse", "Verse on repeat"'''
    print(f'sections.loop({sectionName})')

def loop_the_solo(sectionName: str) -> None:
    '''Loop marked section
    Commands (First command is mostly the most common): "Loop the solo", "Cycle the solo", "Round on the lead", "Vamp on the solo", "Woodshed the licks", "Drill the lead", "Solo on repeat", "Jam section on loop"'''
    print(f'sections.loop({sectionName})')

def clear_loop() -> None:
    '''Remove active loop
    Commands (First command is mostly the most common): "Clear loop", "Kill the loop", "Stop cycling", "Break the loop", "One-shot it", "Straight through", "No more looping", "Linear playback"'''
    print('player.clearLoop()')

def isolate_vocals(stemType: str) -> None:
    '''Focus on vocal part
    Commands (First command is mostly the most common): "Isolate vocals", "Just vox", "Vocals up front", "Singer only", "Give me the vocalist", "Pull out the vox", "Lead vocal only", "Strip to vocals"'''
    print(f'stems.isolate({stemType})')

def isolate_guitar(stemType: str) -> None:
    '''Solo guitar track by muting all other tracksFocus on guitar part
    Commands (First command is mostly the most common): "Isolate guitar", "Just the axe", "Guitar only", "Six-string only", "Pull out the guitar", "Strings only", "Guit only", "Let me hear the guitar"'''
    print(f'stems.isolate({stemType})')

def isolate_bass(stemType: str) -> None:
    '''Solo bass by muting all other tracksFocus on bass part
    Commands (First command is mostly the most common): "Isolate bass", "Just the low end", "Bass only", "Bottom only", "Pull out the bass", "Low-end only", "Let me hear what's walking", "Just the groove"'''
    print(f'stems.isolate({stemType})')

def isolate_drums(stemType: str) -> None:
    '''Solo drums by muting all other tracksFocus on drum part
    Commands (First command is mostly the most common): "Isolate drums", "Just the kit", "Drums only", "Skins only", "Pull out the beat", "Percussion only", "Rhythm section", "Beat only"'''
    print(f'stems.isolate({stemType})')

def isolate_piano(stemType: str) -> None:
    '''Solo piano by muting all other tracks. If there is both a piano and keys track, mute solo the piano, leaving the keys mute.Focus on piano part
    Commands (First command is mostly the most common): "Isolate piano", "Just the keys", "Piano only", "Ivories only", "Pull out the keys", "Keys only", "Let me hear the piano", "Just the chord comps"'''
    print(f'stems.isolate({stemType})')

def remove_vocals(stemType: str) -> None:
    '''Mute the vocal track, keeping all of the other tracks unchanged.For vocal practice with backing
    Commands (First command is mostly the most common): "Remove vocals", "Drop the vox", "Scratch track", "Backing only", "Pull the singer", "Track only", "Minus one", "Karaoke mode"'''
    print(f'stems.mute({stemType})')

def turn_down_drums(stemType: str, volume: int) -> None:
    '''Change the drum track volume. Reduce drum volume by increments of specific number
    Commands (First command is mostly the most common): "Turn down drums", "Ease off the kit", "Bury the drums a bit", "Drums in the back", "Less thump", "Easy on the skins", "Pull back the beat", "Drums too hot"'''
    print(f'stems.setVolume({stemType}, CurrentVol+{volume})')

def turn_up_bass(stemType: str, volume: int) -> None:
    '''Change the bass track volume. Increase bass volume by increments of specific number
    Commands (First command is mostly the most common): "Turn up bass", "More bottom", "Pump the bass", "Beef up the low end", "Bass in the face", "Fatten the bottom", "Give me more groove", "Thump it up"'''
    print(f'stems.setVolume({stemType}, CurrentVol-{volume})')

def reset_mix() -> None:
    '''Reset all volumes from the mix back to the default volume of all tracksReset all stem volumes
    Commands (First command is mostly the most common): "Reset mix", "Flatten the faders", "Back to the board", "Zero the mix", "Default balance", "Level the mix", "Reset the balance", "Home position"'''
    print('stems.resetMix()')

def show_all_instruments() -> None:
    '''Unmute all instruments, keeping the current volume.Show all instrument stems
    Commands (First command is mostly the most common): "Show all instruments", "Full band", "Everything in", "All players", "Full mix", "Bring it all back", "Stack it all", "Full ensemble"'''
    print('stems.showAll()')

def metronome_on() -> None:
    '''Enable metronome
    Commands (First command is mostly the most common): "Metronome on", "Click track", "Give me the click", "Click in", "Gimme some time", "Drop the metronome", "Beat keeper", "Time keeper"'''
    print(f'metronome.enable(True)')

def metronome_off() -> None:
    '''Disable metronome
    Commands (First command is mostly the most common): "Metronome off", "Kill the click", "No click", "Click out", "Ditch the metronome", "Free time", "Off the grid", "No more tick-tock"'''
    print(f'metronome.enable()')

def set_metronome_by_bpm(bpm: int) -> None:
    '''Set specific metronome tempo
    Commands (First command is mostly the most common): "Set metronome to specific number", "Click at specific number", "Tempo specific number", "specific number on the dial", "Clock it at specific number", "Quarter = specific number", "specific number clicks", "specific number on the metro"'''
    print(f'metronome.setTempo({bpm})')

def count_in(bars: int) -> None:
    '''Add count-in before playing
    Commands (First command is mostly the most common): "Count in", "Count me off", "Give me four", "Count it in", "Kick me in", "Four clicks in", "Lead-in count", "Click me in"'''
    print(f'player.countIn({4 if bars == None else bars})')

def record_take() -> None:
    '''Start recording performance
    Commands (First command is mostly the most common): "Record take", "Lay it down", "Roll on this", "Drop a take", "Capture this", "Hit record", "Take it", "Get this on tape", "Track this"'''
    print('recorder.start()')

def stop_recording() -> None:
    '''Stop current recording, when the user say below command:
    Commands (First command is mostly the most common): "Stop recording", "That's a take", "Cut the tape", "Got it", "In the can", "That's the one", "Print it", "End of take", "That's a wrap"'''
    print('recorder.stop()')

def compare_takes() -> None:
    '''Compare multiple recordings
    Commands (First command is mostly the most common): "Compra takes", "Let's hear the takes", "A/B them", "Which one's better", "Play the options", "Take check", "Run the versions", "Let's hear what we got"'''
    print('practice.compareTakes()')

def transpose_up(positive_semitones: int) -> None:
    '''Transpose up by 1 semitone
    Commands (First command is mostly the most common): "Transpose up", "Bump it up", "Kick it up a half", "Up a semi", "Step it up", "Push it up", "Nudge it up", "Half-step up"'''
    print(f'audio.transpose({1 if positive_semitones == None else positive_semitones})')

def transpose_down(negative_semitones: int) -> None:
    '''Transpose down by 1 semitone
    Commands (First command is mostly the most common): "Transpose down", "Take it down", "Drop it a half", "Down a semi", "Step it down", "Nudge it down", "Half-step down", "Bring it down"'''
    print(f'audio.transpose({-1 if negative_semitones == None else negative_semitones})')

def transpose_up_a_whole_step(positive_semitones: int) -> None:
    '''Transpose up by 2 semitones
    Commands (First command is mostly the most common): "Transpose up a whole step", "Up a tone", "Whole step up", "Up two", "Bump it up a whole", "Two frets up", "Major second up", "Step it up a whole"'''
    print(f'audio.transpose({2 if positive_semitones == None else positive_semitones})')

def transpose_down_a_whole_step(negative_semitones: int) -> None:
    '''Transpose down by 2 semitones
    Commands (First command is mostly the most common): "Transpose down a whole step", "Down a tone", "Whole step down", "Down two", "Bump it down a whole", "Two frets down", "Major second down", "Step it down a whole"'''
    print(f'audio_transpose({-2 if negative_semitones == None else negative_semitones})')

# %% [markdown]
# ## pt

# %%
def reproduzir() -> None:
    '''Inicia a reprodução da faixa atual a partir da posição da barra de progresso.
    Este é um dos comandos mais comuns para iniciar a reprodução de música.
    Comandos (o primeiro comando é geralmente o mais comum): "Reproduzir", "Começar", "Iniciar", "Toca aí", "Vamos nessa", "Solta o som", "Manda ver", "Vai lá", "De novo", "Começa outra vez"'''
    print('player.play()')

def pausar() -> None:
    '''Pausa a faixa de música que está sendo reproduzida. Este comando interrompe a reprodução, mas mantém a posição atual na faixa.
    Comandos (o primeiro comando é geralmente o mais comum): "Pausar", "Parar", "Segura aí", "Espera", "Interromper", "Congelar", "Time", "Cortar", "Desligar"'''
    print('player.pause()')

def do_inicio() -> None:
    '''Reinicia a faixa atual do começo sem pausar. Esse comando automaticamente reposiciona a barra de progresso no início da música.
    Se a faixa estiver pausada, ela é reiniciada e começa a tocar imediatamente.
    Comandos (o primeiro comando é geralmente o mais comum): "Do início", "Volta ao começo", "Começar de novo", "Rodar outra vez", "Recomeçar", "Toca de novo"'''
    print(f'player.seek(0)')

def voltar(segundos: int) -> None:
    '''Retrocede a faixa atual por um intervalo predefinido. Esse comando move a barra de progresso para um ponto anterior na música.
    Padrão: voltar 10 segundos.
    Comandos (o primeiro comando é geralmente o mais comum): "Voltar", "Rebobinar", "Volta um pouco", "Deixa eu ouvir de novo", "Mais uma vez nessa parte"'''
    print(f'player.seek(currentTime-{segundos})')

def avancar(segundos: int) -> None:
    '''Avança a reprodução por um intervalo específico ou pula para um ponto mais à frente da faixa.
    Esse comando move a barra de progresso para frente dentro da música atual.
    Padrão: avançar 10 segundos.
    Comandos (o primeiro comando é geralmente o mais comum): "Avançar", "Pular essa parte", "Adiantar", "Ir para frente", "Passar essa parte"'''
    print(f'player.seek(currentTime+{segundos})')

def diminuir_ritmo_muito(bpm: int) -> None:
    '''Diminui a velocidade de reprodução de forma mais intensa, reduzindo o tempo em BPMs.
    Padrão: reduzir -20 BPM do BPM atual.
    Comandos (o primeiro comando é geralmente o mais comum): "Diminuir muito o ritmo", "Bem devagar", "Ritmo de tartaruga", "Super lento", "Modo calmaria"'''
    print(f'audio.setBpm(currentBpm-{bpm})')

def metade_da_velocidade() -> None:
    '''Reduz a velocidade de reprodução drasticamente para metade do tempo.
    O BPM atual é reduzido pela metade.
    Comandos (o primeiro comando é geralmente o mais comum): "Metade da velocidade", "Cortar pela metade", "Ritmo de treino", "Música lenta", "Modo estudo"'''
    print(f'audio.setBpm(currentBpm/2)')

def acelerar(bpm: int) -> None:
    '''Aumenta a velocidade de reprodução, acelerando o tempo em BPMs.
    Padrão: aumentar +10 BPM do BPM atual.
    Comandos (o primeiro comando é geralmente o mais comum): "Acelerar", "Mais rápido", "Aumentar ritmo", "Dar gás", "Pisar fundo", "Dobrar o ritmo", "Vamos acelerar"'''
    print(f'audio.setBpm(currentBpm+{bpm})')

def tocar() -> None:
    '''Inicia a reprodução da faixa atual a partir da posição da barra de busca.
    Esse é um dos comandos mais comuns para iniciar a reprodução de música.
    Comandos (O primeiro comando é geralmente o mais comum): "Tocar", "Começar", "Iniciar", "Manda ver", "Vamos lá", "Solta o som", "Comece a contagem", "Dá o play", "Vai daí", "Do início", "Começar de novo"'''
    print('player.play()')

def diminuir_velocidade(bpm: int) -> None:
    '''Diminui a velocidade de reprodução, reduzindo o tempo em BPMs.
    O padrão é reduzir 10 BPMs do tempo atual.
    Comandos: "Diminuir velocidade", "Abaixa um pouco", "Relaxa", "Desacelera", "Tira o pé", "Joga um freio", "Baixa a batida", "Sem pressa"'''
    print(f'audio.setBpm(currentBpm-{bpm})')

def diminuir_muito(bpm: int) -> None:
    '''Diminui bastante a velocidade de reprodução, reduzindo o tempo em BPMs.
    O padrão é reduzir 20 BPMs do tempo atual.
    Comandos: "Diminuir muito", "Devagar", "Modo tartaruga", "Desaceleração total", "Modo câmera lenta", "Passo de caracol", "Andamento glacial"'''
    print(f'audio.setBpm(currentBpm-{bpm})')

def velocidade_normal() -> None:
    '''Restaura o tempo original da música.
    Comandos: "Velocidade normal", "De volta ao normal", "Como está escrito", "No tempo certo", "Ritmo original", "Sem alterações"'''
    print(f'audio.setBpm(originalBpm)')

def definir_tempo_por_porcentagem(porcentagem: int) -> None:
    '''Define o tempo para uma porcentagem específica escolhida pelo usuário.
    Comandos: "Definir tempo para X por cento", "Coloca em X por cento", "Marca em X por cento", "Ritmo de X por cento"'''
    print(f'audio.setSpeed({porcentagem})')

def definir_tempo_por_bpm(bpm: int) -> None:
    '''Define o tempo para um BPM específico escolhido pelo usuário.
    Comandos: "Definir tempo para X BPM", "Coloca em X BPM", "Marca em X BPM", "Ritmo de X BPM"'''
    print(f'audio.setBpm({bpm})')

def loopar_trecho(tempoInicio: int, tempoFim: int) -> None:
    '''Ativa o loop em um trecho da música.
    Comandos: "Loopar este trecho", "Repetir esta parte", "Ciclo aqui", "De novo", "Trecho em loop", "Vamos praticar esse pedaço"'''
    print(f'player.setLoop({tempoFim-tempoInicio})')

def ir_para_refrao(nomeSecao: str) -> None:
    '''Avança para o refrão mais próximo.
    Comandos: "Ir para o refrão", "Pula para o refrão", "Direto para o refrão", "Vamos para a parte principal"'''
    print(f'sections.jumpTo({nomeSecao})')

def ir_para_verso(nomeSecao: str) -> None:
    '''Avança para o próximo verso.
    Comandos: "Ir para o verso", "Pula para a estrofe", "Direto para o verso"'''
    print(f'sections.jumpTo({nomeSecao})')

def ir_para_solo(nomeSecao: str) -> None:
    '''Avança para o solo mais próximo.
    Comandos: "Ir para o solo", "Pula para o solo", "Vai para a parte instrumental"'''
    print(f'sections.jumpTo({nomeSecao})')

def loopar_refrao(nomeSecao: str) -> None:
    '''Coloca o refrão em loop.
    Comandos: "Loopar o refrão", "Repetir o refrão", "Ciclo no refrão", "De novo o refrão"'''
    print(f'sections.loop({nomeSecao})')

def loopar_verso(nomeSecao: str) -> None:
    '''Coloca o verso em loop.
    Comandos: "Loopar o verso", "Repetir o verso", "Ciclo no verso", "De novo o verso"'''
    print(f'sections.loop({nomeSecao})')

def loopar_solo(nomeSecao: str) -> None:
    '''Coloca o solo em loop.
    Comandos: "Loopar o solo", "Repetir o solo", "Ciclo no solo", "De novo o solo"'''
    print(f'sections.loop({nomeSecao})')

def limpar_loop() -> None:
    '''Remove o loop ativo.
    Comandos: "Parar loop", "Cancelar loop", "Sem repetição", "Reprodução linear"'''
    print('player.clearLoop()')

def isolar_vocais(tipo_de_stem: str) -> None:
    '''Focar na parte vocal.
    Comandos (O primeiro comando é geralmente o mais comum): "Isolar vocais", "Só os vocais", "Vocais em destaque", "Apenas o cantor", "Me dê o vocalista", "Extrair os vocais", "Vocal principal apenas", "Reduzir para vocais"'''
    print(f'stems.isolate({tipo_de_stem})')

def isolar_guitarra(tipo_de_stem: str) -> None:
    '''Solo de guitarra silenciando todas as outras faixas. Focar na parte da guitarra.
    Comandos (O primeiro comando é geralmente o mais comum): "Isolar guitarra", "Só o machado", "Guitarra apenas", "Seis cordas apenas", "Extrair a guitarra", "Cordas apenas", "Guit apenas", "Deixe-me ouvir a guitarra"'''
    print(f'stems.isolate({tipo_de_stem})')

def isolar_baixo(tipo_de_stem: str) -> None:
    '''Solo de baixo silenciando todas as outras faixas. Focar na parte do baixo.
    Comandos (O primeiro comando é geralmente o mais comum): "Isolar baixo", "Só os graves", "Baixo apenas", "Graves apenas", "Extrair o baixo", "Graves apenas", "Deixe-me ouvir o que está caminhando", "Só o groove"'''
    print(f'stems.isolate({tipo_de_stem})')

def isolar_bateria(tipo_de_stem: str) -> None:
    '''Solo de bateria silenciando todas as outras faixas. Focar na parte da bateria.
    Comandos (O primeiro comando é geralmente o mais comum): "Isolar bateria", "Só o kit", "Bateria apenas", "Peles apenas", "Extrair a batida", "Percussão apenas", "Seção rítmica", "Batida apenas"'''
    print(f'stems.isolate({tipo_de_stem})')

def isolar_piano(tipo_de_stem: str) -> None:
    '''Solo de piano silenciando todas as outras faixas. Se houver faixas de piano e teclados, silenciar apenas o piano, deixando os teclados mudos. Focar na parte do piano.
    Comandos (O primeiro comando é geralmente o mais comum): "Isolar piano", "Só os teclados", "Piano apenas", "Marfins apenas", "Extrair os teclados", "Teclados apenas", "Deixe-me ouvir o piano", "Só os acordes de acompanhamento"'''
    print(f'stems.isolate({tipo_de_stem})')

def remover_vocais(tipo_de_stem: str) -> None:
    '''Silenciar a faixa vocal, mantendo todas as outras faixas inalteradas. Para prática vocal com acompanhamento.
    Comandos (O primeiro comando é geralmente o mais comum): "Remover vocais", "Tirar os vocais", "Faixa de rascunho", "Acompanhamento apenas", "Tirar o cantor", "Faixa apenas", "Menos um", "Modo karaokê"'''
    print(f'stems.mute({tipo_de_stem})')

def abaixar_bateria(tipo_de_stem: str, volume: int) -> None:
    '''Alterar o volume da faixa de bateria. Reduzir o volume da bateria em incrementos de um número específico.
    Comandos (O primeiro comando é geralmente o mais comum): "Abaixar bateria", "Diminuir o kit", "Enterrar um pouco a bateria", "Bateria no fundo", "Menos batida", "Leve nas peles", "Recuar a batida", "Bateria muito alta"'''
    print(f'stems.setVolume({tipo_de_stem}, CurrentVol+{volume})')

def aumentar_baixo(tipo_de_stem: str, volume: int) -> None:
    '''Alterar o volume da faixa de baixo. Aumentar o volume do baixo em incrementos de um número específico.
    Comandos (O primeiro comando é geralmente o mais comum): "Aumentar baixo", "Mais graves", "Bombear o baixo", "Engrossar os graves", "Baixo na cara", "Engordar os graves", "Me dê mais groove", "Aumentar a batida"'''
    print(f'stems.setVolume({tipo_de_stem}, CurrentVol-{volume})')

def resetar_mixagem() -> None:
    '''Redefinir todos os volumes da mixagem para o volume padrão de todas as faixas. Redefinir todos os volumes de stem.
    Comandos (O primeiro comando é geralmente o mais comum): "Resetar mixagem", "Aplanar os faders", "Voltar para a mesa", "Zerar a mixagem", "Equilíbrio padrão", "Nivelar a mixagem", "Redefinir o equilíbrio", "Posição inicial"'''
    print('stems.resetMix()')

def mostrar_todos_instrumentos() -> None:
    '''Desmutar todos os instrumentos, mantendo o volume atual. Mostrar todos os stems de instrumentos.
    Comandos (O primeiro comando é geralmente o mais comum): "Mostrar todos os instrumentos", "Banda completa", "Tudo dentro", "Todos os músicos", "Mixagem completa", "Trazer tudo de volta", "Empilhar tudo", "Conjunto completo"'''
    print('stems.showAll()')

def metronomo_ligado() -> None:
    '''Ativar o metrônomo.
    Comandos (O primeiro comando é geralmente o mais comum): "Metrônomo ligado", "Clique de tempo", "Me dê o clique", "Clique dentro", "Me dê um tempo", "Soltar o metrônomo", "Marcador de batida", "Marcador de tempo"'''
    print(f'metronome.enable(True)')

def metronomo_desligado() -> None:
    '''Desativar o metrônomo.
    Comandos (O primeiro comando é geralmente o mais comum): "Metrônomo desligado", "Matar o clique", "Sem clique", "Clique fora", "Descartar o metrônomo", "Tempo livre", "Fora da grade", "Sem mais tic-tac"'''
    print(f'metronome.enable()')

def definir_metronomo_por_bpm(bpm: int) -> None:
    '''Definir o tempo específico do metrônomo.
    Comandos (O primeiro comando é geralmente o mais comum): "Definir metrônomo para número específico", "Clique em número específico", "Tempo número específico", "número específico no dial", "Marcar em número específico", "Semibreve = número específico", "número específico de cliques", "número específico no metrônomo"'''
    print(f'metronome.setTempo({bpm})')

def contar_entrada(barras: int) -> None:
    '''Adicionar contagem de entrada antes de tocar.
    Comandos (O primeiro comando é geralmente o mais comum): "Contar entrada", "Me contar", "Me dê quatro", "Contar", "Me lançar", "Quatro cliques de entrada", "Contagem de introdução", "Me clicar"'''
    print(f'player.countIn({4 if barras == None else barras})')

def gravar_tomada() -> None:
    '''Começar a gravar a performance.
    Comandos (O primeiro comando é geralmente o mais comum): "Gravar tomada", "Registrar", "Gravar isso", "Soltar uma tomada", "Capturar isso", "Apertar gravar", "Pegar isso", "Gravar isso na fita", "Faixa isso"'''
    print('recorder.start()')

def parar_gravacao() -> None:
    '''Parar a gravação atual, quando o usuário disser o comando abaixo:
    Comandos (O primeiro comando é geralmente o mais comum): "Parar gravação", "Essa é uma tomada", "Cortar a fita", "Entendi", "Na lata", "Essa é a certa", "Imprimir isso", "Fim da tomada", "Isso é um encerramento"'''
    print('recorder.stop()')

def comparar_tomadas() -> None:
    '''Comparar várias gravações.
    Comandos (O primeiro comando é geralmente o mais comum): "Comparar tomadas", "Vamos ouvir as tomadas", "A/B elas", "Qual é a melhor", "Tocar as opções", "Verificação de tomada", "Executar as versões", "Vamos ouvir o que temos"'''
    print('practice.compareTakes()')

def transpor_para_cima(semitons_positivos: int) -> None:
    '''Transpor para cima em 1 semitom.
    Comandos (O primeiro comando é geralmente o mais comum): "Transpor para cima", "Aumentar", "Aumentar meio tom", "Subir um semi", "Subir", "Empurrar para cima", "Ajustar para cima", "Meio passo para cima"'''
    print(f'audio.transpose({1 if semitons_positivos == None else semitons_positivos})')

def transpor_para_baixo(semitons_negativos: int) -> None:
    '''Transpor para baixo em 1 semitom.
    Comandos (O primeiro comando é geralmente o mais comum): "Transpor para baixo", "Diminuir", "Diminuir meio tom", "Descer um semi", "Descer", "Ajustar para baixo", "Meio passo para baixo", "Trazer para baixo"'''
    print(f'audio.transpose({-1 if semitons_negativos == None else semitons_negativos})')

def transpor_para_cima_um_passo_inteiro(semitons_positivos: int) -> None:
    '''Transpor para cima em 2 semitons.
    Comandos (O primeiro comando é geralmente o mais comum): "Transpor para cima um passo inteiro", "Subir um tom", "Passo inteiro para cima", "Subir dois", "Aumentar um inteiro", "Subir dois trastes", "Segunda maior para cima", "Subir um passo inteiro"'''
    print(f'audio.transpose({2 if semitons_positivos == None else semitons_positivos})')

def transpor_para_baixo_um_passo_inteiro(semitons_negativos: int) -> None:
    '''Transpor para baixo em 2 semitons.
    Comandos (O primeiro comando é geralmente o mais comum): "Transpor para baixo um passo inteiro", "Descer um tom", "Passo inteiro para baixo", "Descer dois", "Diminuir um inteiro", "Descer dois trastes", "Segunda maior para baixo", "Descer um passo inteiro"'''
    print(f'audio.transpose({-2 if semitons_negativos == None else semitons_negativos})')

# %% [markdown]
# # OPENAI
#
# consegue realizar operacoes mais complexos, e ter uma certa flexibilidade em comandos. em tempo perde um pouco pra (gemini).

# %% [markdown]
# ## fns en

# %%
moises_fns_openai_en = [
    {   
        "type": "function",
        "function": {
        "name": "play",
        "description": "Start playback of the current track from where the seekbar is positioned. This is one of the most common intents used for initiating music playback.",
        "parameters": {
            "type": "object",
            "properties": {},
            "required": [],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "pause",
        "description": "Pause the currently playing music track. This intent stops playback while maintaining the current position in the track.",
        "parameters": {
            "type": "object",
            "properties": {},
            "required": [],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "from_the_top",
        "description": "Restart the current track from its beginning without pausing. This command automatically repositions the seekbar to the start of the song.",
        "parameters": {
            "type": "object",
            "properties": {},
            "required": [],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "go_back",
        "description": "Rewind the current track by a preset interval. This intent moves the seekbar to an earlier point in the song.",
        "parameters": {
            "type": "object",
            "properties": {
                "seconds": {
                    "type": "integer",
                    "description": "Number of seconds to rewind.",
                }
            },
            "required": ["seconds"],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "skip_ahead",
        "description": "Advance the playback by a specified interval or jump to a later point in the track. This intent moves the seekbar forward within the current song.",
        "parameters": {
            "type": "object",
            "properties": {
                "seconds": {
                    "type": "integer",
                    "description": "Number of seconds to skip ahead.",
                }
            },
            "required": ["seconds"],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "slow_down",
        "description": "Decrease the playback speed. This command reduces the tempo in BPMs.",
        "parameters": {
            "type": "object",
            "properties": {
                "bpm": {
                    "type": "integer",
                    "description": "Number of BPMs to reduce from the current tempo.",
                }
            },
            "required": ["bpm"],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "slow_down_a_lot",
        "description": "Decrease the playback speed. This command reduces the tempo in BPMs dramatically.",
        "parameters": {
            "type": "object",
            "properties": {
                "bpm": {
                    "type": "integer",
                    "description": "Number of BPMs to reduce from the current tempo.",
                }
            },
            "required": ["bpm"],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "half_speed",
        "description": "Decrease the playback speed. This command reduces the tempo in BPMs dramatically to half of the tempo.",
        "parameters": {
            "type": "object",
            "properties": {},
            "required": [],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "speed_up",
        "description": "Increase the playback speed. This intent accelerates the tempo.",
        "parameters": {
            "type": "object",
            "properties": {
                "bpm": {
                    "type": "integer",
                    "description": "Number of BPMs to increase from the current tempo.",
                }
            },
            "required": ["bpm"],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "normal_speed",
        "description": "Reset the tempo to its original BPM.",
        "parameters": {
            "type": "object",
            "properties": {},
            "required": [],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "set_tempo_by_percent",
        "description": "Set tempo to a specific user speed setting.",
        "parameters": {
            "type": "object",
            "properties": {
                "percentage": {
                    "type": "integer",
                    "description": "Percentage of the original tempo to set.",
                }
            },
            "required": ["percentage"],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "set_tempo_by_bpm",
        "description": "Set tempo to a specific BPM requested by the user.",
        "parameters": {
            "type": "object",
            "properties": {
                "bpm": {
                    "type": "integer",
                    "description": "Specific BPM to set.",
                }
            },
            "required": ["bpm"],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "loop_this_section",
        "description": "Activate loop on the current section.",
        "parameters": {
            "type": "object",
            "properties": {
                "startTime": {
                    "type": "integer",
                    "description": "Start time of the section in seconds.",
                },
                "endTime": {
                    "type": "integer",
                    "description": "End time of the section in seconds.",
                },
            },
            "required": ["startTime", "endTime"],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "go_to_chorus",
        "description": "Seek forward to the nearest chorus.",
        "parameters": {
            "type": "object",
            "properties": {
                "sectionName": {
                    "type": "string",
                    "description": "Name of the chorus section.",
                }
            },
            "required": ["sectionName"],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "go_to_verse",
        "description": "Seek forward to the nearest verse.",
        "parameters": {
            "type": "object",
            "properties": {
                "sectionName": {
                    "type": "string",
                    "description": "Name of the verse section.",
                }
            },
            "required": ["sectionName"],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "go_to_solo",
        "description": "Seek forward to the nearest solo.",
        "parameters": {
            "type": "object",
            "properties": {
                "sectionName": {
                    "type": "string",
                    "description": "Name of the solo section.",
                }
            },
            "required": ["sectionName"],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "loop_the_chorus",
        "description": "Loop the marked chorus section.",
        "parameters": {
            "type": "object",
            "properties": {
                "sectionName": {
                    "type": "string",
                    "description": "Name of the chorus section.",
                }
            },
            "required": ["sectionName"],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "loop_the_verse",
        "description": "Loop the marked verse section.",
        "parameters": {
            "type": "object",
            "properties": {
                "sectionName": {
                    "type": "string",
                    "description": "Name of the verse section.",
                }
            },
            "required": ["sectionName"],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "loop_the_solo",
        "description": "Loop the marked solo section.",
        "parameters": {
            "type": "object",
            "properties": {
                "sectionName": {
                    "type": "string",
                    "description": "Name of the solo section.",
                }
            },
            "required": ["sectionName"],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "clear_loop",
        "description": "Remove active loop.",
        "parameters": {
            "type": "object",
            "properties": {},
            "required": [],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "isolate_vocals",
        "description": "Focus on the vocal part by muting all other tracks.",
        "parameters": {
            "type": "object",
            "properties": {
                "stemType": {
                    "type": "string",
                    "description": "Type of stem to isolate (e.g., 'vocals').",
                }
            },
            "required": ["stemType"],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "isolate_guitar",
        "description": "Focus on the guitar part by muting all other tracks.",
        "parameters": {
            "type": "object",
            "properties": {
                "stemType": {
                    "type": "string",
                    "description": "Type of stem to isolate (e.g., 'guitar').",
                }
            },
            "required": ["stemType"],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "isolate_bass",
        "description": "Focus on the bass part by muting all other tracks.",
        "parameters": {
            "type": "object",
            "properties": {
                "stemType": {
                    "type": "string",
                    "description": "Type of stem to isolate (e.g., 'bass').",
                }
            },
            "required": ["stemType"],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "isolate_drums",
        "description": "Focus on the drum part by muting all other tracks.",
        "parameters": {
            "type": "object",
            "properties": {
                "stemType": {
                    "type": "string",
                    "description": "Type of stem to isolate (e.g., 'drums').",
                }
            },
            "required": ["stemType"],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "isolate_piano",
        "description": "Focus on the piano part by muting all other tracks.",
        "parameters": {
            "type": "object",
            "properties": {
                "stemType": {
                    "type": "string",
                    "description": "Type of stem to isolate (e.g., 'piano').",
                }
            },
            "required": ["stemType"],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "remove_vocals",
        "description": "Mute the vocal track, keeping all other tracks unchanged.",
        "parameters": {
            "type": "object",
            "properties": {
                "stemType": {
                    "type": "string",
                    "description": "Type of stem to mute (e.g., 'vocals').",
                }
            },
            "required": ["stemType"],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "turn_down_drums",
        "description": "Reduce the drum track volume by a specified amount.",
        "parameters": {
            "type": "object",
            "properties": {
                "stemType": {
                    "type": "string",
                    "description": "Type of stem to adjust (e.g., 'drums').",
                },
                "volume": {
                    "type": "integer",
                    "description": "Amount to reduce the volume by.",
                },
            },
            "required": ["stemType", "volume"],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "turn_up_bass",
        "description": "Increase the bass track volume by a specified amount.",
        "parameters": {
            "type": "object",
            "properties": {
                "stemType": {
                    "type": "string",
                    "description": "Type of stem to adjust (e.g., 'bass').",
                },
                "volume": {
                    "type": "integer",
                    "description": "Amount to increase the volume by.",
                },
            },
            "required": ["stemType", "volume"],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "reset_mix",
        "description": "Reset all volumes from the mix back to the default volume of all tracks.",
        "parameters": {
            "type": "object",
            "properties": {},
            "required": [],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "show_all_instruments",
        "description": "Unmute all instruments, keeping the current volume.",
        "parameters": {
            "type": "object",
            "properties": {},
            "required": [],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "metronome_on",
        "description": "Enable the metronome.",
        "parameters": {
            "type": "object",
            "properties": {},
            "required": [],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "metronome_off",
        "description": "Disable the metronome.",
        "parameters": {
            "type": "object",
            "properties": {},
            "required": [],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "set_metronome_by_bpm",
        "description": "Set the metronome to a specific BPM.",
        "parameters": {
            "type": "object",
            "properties": {
                "bpm": {
                    "type": "integer",
                    "description": "Specific BPM to set the metronome to.",
                }
            },
            "required": ["bpm"],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "count_in",
        "description": "Add a count-in before playing.",
        "parameters": {
            "type": "object",
            "properties": {
                "bars": {
                    "type": "integer",
                    "description": "Number of bars for the count-in.",
                }
            },
            "required": ["bars"],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "record_take",
        "description": "Start recording a performance.",
        "parameters": {
            "type": "object",
            "properties": {},
            "required": [],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "stop_recording",
        "description": "Stop the current recording.",
        "parameters": {
            "type": "object",
            "properties": {},
            "required": [],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "compare_takes",
        "description": "Compare multiple recordings.",
        "parameters": {
            "type": "object",
            "properties": {},
            "required": [],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "transpose_up",
        "description": "Transpose up by 1 semitone.",
        "parameters": {
            "type": "object",
            "properties": {
                "positive_semitones": {
                    "type": "integer",
                    "description": "Number of semitones to transpose up.",
                }
            },
            "required": ["positive_semitones"],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "transpose_down",
        "description": "Transpose down by 1 semitone.",
        "parameters": {
            "type": "object",
            "properties": {
                "negative_semitones": {
                    "type": "integer",
                    "description": "Number of semitones to transpose down.",
                }
            },
            "required": ["negative_semitones"],}
        },
    },
    {   
        "type": "function",
        "function": {
        "name": "transpose_up_a_whole_step",
        "description": "Transpose up by 2 semitones.",
        "parameters": {
            "type": "object",
            "properties": {
                "positive_semitones": {
                    "type": "integer",
                    "description": "Number of semitones to transpose up.",
                }
            },
            "required": ["positive_semitones"],}
        },
    },
    {   
        "type": "function",
        "function": {
            "name": "transpose_down_a_whole_step",
            "description": "Transpose down by 2 semitones.",
            "parameters": {
                "type": "object",
                "properties": {
                    "negative_semitones": {
                        "type": "integer",
                        "description": "Number of semitones to transpose down.",
                    }
                },
                "required": ["negative_semitones"],}
            },
    },
]

# %% [markdown]
# ## fns pt

# %%
moises_fns_openai_pt = [
    {
        "type": "function",
        "function": {
            "name": "reproduzir",
            "description": "Inicia a reprodução da faixa atual a partir da posição da barra de progresso. Este é um dos comandos mais comuns para iniciar a reprodução de música.",
            "parameters": {
                "type": "object",
                "properties": {},
                "required": []
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "pausar",
            "description": "Pausa a faixa de música que está sendo reproduzida. Este comando interrompe a reprodução, mas mantém a posição atual na faixa.",
            "parameters": {
                "type": "object",
                "properties": {},
                "required": []
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "do_inicio",
            "description": "Reinicia a faixa atual do começo sem pausar. Esse comando automaticamente reposiciona a barra de progresso no início da música. Se a faixa estiver pausada, ela é reiniciada e começa a tocar imediatamente.",
            "parameters": {
                "type": "object",
                "properties": {},
                "required": []
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "voltar",
            "description": "Retrocede a faixa atual por um intervalo predefinido. Esse comando move a barra de progresso para um ponto anterior na música. Padrão: voltar 10 segundos.",
            "parameters": {
                "type": "object",
                "properties": {
                    "segundos": {
                        "type": "integer",
                        "description": "Número de segundos para retroceder."
                    }
                },
                "required": ["segundos"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "avancar",
            "description": "Avança a reprodução por um intervalo específico ou pula para um ponto mais à frente da faixa. Esse comando move a barra de progresso para frente dentro da música atual. Padrão: avançar 10 segundos.",
            "parameters": {
                "type": "object",
                "properties": {
                    "segundos": {
                        "type": "integer",
                        "description": "Número de segundos para avançar."
                    }
                },
                "required": ["segundos"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "diminuir_ritmo",
            "description": "Diminui a velocidade de reprodução, reduzindo o tempo em BPMs. Padrão: reduzir -10 BPM do BPM atual.",
            "parameters": {
                "type": "object",
                "properties": {
                    "bpm": {
                        "type": "integer",
                        "description": "Quantidade de BPMs para diminuir."
                    }
                },
                "required": ["bpm"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "diminuir_ritmo_muito",
            "description": "Diminui a velocidade de reprodução de forma mais intensa, reduzindo o tempo em BPMs. Padrão: reduzir -20 BPM do BPM atual.",
            "parameters": {
                "type": "object",
                "properties": {
                    "bpm": {
                        "type": "integer",
                        "description": "Quantidade de BPMs para diminuir."
                    }
                },
                "required": ["bpm"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "metade_da_velocidade",
            "description": "Reduz a velocidade de reprodução drasticamente para metade do tempo. O BPM atual é reduzido pela metade.",
            "parameters": {
                "type": "object",
                "properties": {},
                "required": []
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "acelerar",
            "description": "Aumenta a velocidade de reprodução, acelerando o tempo em BPMs. Padrão: aumentar +10 BPM do BPM atual.",
            "parameters": {
                "type": "object",
                "properties": {
                    "bpm": {
                        "type": "integer",
                        "description": "Quantidade de BPMs para aumentar."
                    }
                },
                "required": ["bpm"]
            }
        }
    },
        {
        "type": "function",
        "function": {
            "name": "tocar",
            "description": "Inicia a reprodução da faixa atual a partir da posição da barra de busca. Esse é um dos comandos mais comuns para iniciar a reprodução de música.",
            "parameters": {
                "type": "object",
                "properties": {},
                "required": []
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "diminuir_velocidade",
            "description": "Diminui a velocidade de reprodução, reduzindo o tempo em BPMs. O padrão é reduzir 10 BPMs do tempo atual.",
            "parameters": {
                "type": "object",
                "properties": {
                    "bpm": {
                        "type": "integer",
                        "description": "Quantidade de BPMs para diminuir."
                    }
                },
                "required": ["bpm"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "diminuir_muito",
            "description": "Diminui bastante a velocidade de reprodução, reduzindo o tempo em BPMs. O padrão é reduzir 20 BPMs do tempo atual.",
            "parameters": {
                "type": "object",
                "properties": {
                    "bpm": {
                        "type": "integer",
                        "description": "Quantidade de BPMs para diminuir."
                    }
                },
                "required": ["bpm"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "velocidade_normal",
            "description": "Restaura o tempo original da música.",
            "parameters": {
                "type": "object",
                "properties": {},
                "required": []
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "definir_tempo_por_porcentagem",
            "description": "Define o tempo para uma porcentagem específica escolhida pelo usuário.",
            "parameters": {
                "type": "object",
                "properties": {
                    "porcentagem": {
                        "type": "integer",
                        "description": "Porcentagem do tempo original."
                    }
                },
                "required": ["porcentagem"]
            }
        }
    },
        {
        "type": "function",
        "function": {
            "name": "definir_tempo_por_bpm",
            "description": "Define o tempo para um BPM específico escolhido pelo usuário.",
            "parameters": {
                "type": "object",
                "properties": {
                    "bpm": {
                        "type": "integer",
                        "description": "BPM desejado."
                    }
                },
                "required": ["bpm"]
            }
        }
    },
        {
        "type": "function",
        "function": {
            "name": "loopar_trecho",
            "description": "Ativa o loop em um trecho da música.",
            "parameters": {
                "type": "object",
                "properties": {
                    "tempoInicio": {
                        "type": "integer",
                        "description": "Tempo de início do trecho em segundos."
                    },
                    "tempoFim": {
                        "type": "integer",
                        "description": "Tempo de fim do trecho em segundos."
                    }
                },
                "required": ["tempoInicio", "tempoFim"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "ir_para_refrao",
            "description": "Avança para o refrão mais próximo.",
            "parameters": {
                "type": "object",
                "properties": {
                    "nomeSecao": {
                        "type": "string",
                        "description": "Nome da seção do refrão."
                    }
                },
                "required": ["nomeSecao"]
            }
        }
    },
        {
        "type": "function",
        "function": {
            "name": "ir_para_verso",
            "description": "Avança para o próximo verso.",
            "parameters": {
                "type": "object",
                "properties": {
                    "nomeSecao": {
                        "type": "string",
                        "description": "Nome da seção do verso."
                    }
                },
                "required": ["nomeSecao"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "ir_para_solo",
            "description": "Avança para o solo mais próximo.",
            "parameters": {
                "type": "object",
                "properties": {
                    "nomeSecao": {
                        "type": "string",
                        "description": "Nome da seção do solo."
                    }
                },
                "required": ["nomeSecao"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "loopar_refrao",
            "description": "Coloca o refrão em loop.",
            "parameters": {
                "type": "object",
                "properties": {
                    "nomeSecao": {
                        "type": "string",
                        "description": "Nome da seção do refrão."
                    }
                },
                "required": ["nomeSecao"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "loopar_verso",
            "description": "Coloca o verso em loop.",
            "parameters": {
                "type": "object",
                "properties": {
                    "nomeSecao": {
                        "type": "string",
                        "description": "Nome da seção do verso."
                    }
                },
                "required": ["nomeSecao"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "loopar_solo",
            "description": "Coloca o solo em loop.",
            "parameters": {
                "type": "object",
                "properties": {
                    "nomeSecao": {
                        "type": "string",
                        "description": "Nome da seção do solo."
                    }
                },
                "required": ["nomeSecao"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "limpar_loop",
            "description": "Remove o loop ativo.",
            "parameters": {
                "type": "object",
                "properties": {},
                "required": []
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "isolar_vocais",
            "description": "Focar na parte vocal.",
            "parameters": {
                "type": "object",
                "properties": {
                    "tipo_de_stem": {
                        "type": "string",
                        "description": "Tipo de stem a ser isolado."
                    }
                },
                "required": ["tipo_de_stem"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "isolar_guitarra",
            "description": "Solo de guitarra silenciando todas as outras faixas. Focar na parte da guitarra.",
            "parameters": {
                "type": "object",
                "properties": {
                    "tipo_de_stem": {
                        "type": "string",
                        "description": "Tipo de stem a ser isolado."
                    }
                },
                "required": ["tipo_de_stem"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "isolar_baixo",
            "description": "Solo de baixo silenciando todas as outras faixas. Focar na parte do baixo.",
            "parameters": {
                "type": "object",
                "properties": {
                    "tipo_de_stem": {
                        "type": "string",
                        "description": "Tipo de stem a ser isolado."
                    }
                },
                "required": ["tipo_de_stem"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "isolar_bateria",
            "description": "Solo de bateria silenciando todas as outras faixas. Focar na parte da bateria.",
            "parameters": {
                "type": "object",
                "properties": {
                    "tipo_de_stem": {
                        "type": "string",
                        "description": "Tipo de stem a ser isolado."
                    }
                },
                "required": ["tipo_de_stem"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "isolar_piano",
            "description": "Solo de piano silenciando todas as outras faixas. Se houver faixas de piano e teclados, silenciar apenas o piano, deixando os teclados mudos. Focar na parte do piano.",
            "parameters": {
                "type": "object",
                "properties": {
                    "tipo_de_stem": {
                        "type": "string",
                        "description": "Tipo de stem a ser isolado."
                    }
                },
                "required": ["tipo_de_stem"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "remover_vocais",
            "description": "Silenciar a faixa vocal, mantendo todas as outras faixas inalteradas. Para prática vocal com acompanhamento.",
            "parameters": {
                "type": "object",
                "properties": {
                    "tipo_de_stem": {
                        "type": "string",
                        "description": "Tipo de stem a ser silenciado."
                    }
                },
                "required": ["tipo_de_stem"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "abaixar_bateria",
            "description": "Alterar o volume da faixa de bateria. Reduzir o volume da bateria em incrementos de um número específico.",
            "parameters": {
                "type": "object",
                "properties": {
                    "tipo_de_stem": {
                        "type": "string",
                        "description": "Tipo de stem da bateria."
                    },
                    "volume": {
                        "type": "integer",
                        "description": "Quantidade de volume para diminuir."
                    }
                },
                "required": ["tipo_de_stem", "volume"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "aumentar_baixo",
            "description": "Alterar o volume da faixa de baixo. Aumentar o volume do baixo em incrementos de um número específico.",
            "parameters": {
                "type": "object",
                "properties": {
                    "tipo_de_stem": {
                        "type": "string",
                        "description": "Tipo de stem do baixo."
                    },
                    "volume": {
                        "type": "integer",
                        "description": "Quantidade de volume para aumentar."
                    }
                },
                "required": ["tipo_de_stem", "volume"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "resetar_mixagem",
            "description": "Redefinir todos os volumes da mixagem para o volume padrão de todas as faixas. Redefinir todos os volumes de stem.",
            "parameters": {
                "type": "object",
                "properties": {},
                "required": []
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "mostrar_todos_instrumentos",
            "description": "Desmutar todos os instrumentos, mantendo o volume atual. Mostrar todos os stems de instrumentos.",
            "parameters": {
                "type": "object",
                "properties": {},
                "required": []
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "metronomo_ligado",
            "description": "Ativar o metrônomo.",
            "parameters": {
                "type": "object",
                "properties": {},
                "required": []
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "metronomo_desligado",
            "description": "Desativar o metrônomo.",
            "parameters": {
                "type": "object",
                "properties": {},
                "required": []
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "definir_metronomo_por_bpm",
            "description": "Definir o tempo específico do metrônomo.",
            "parameters": {
                "type": "object",
                "properties": {
                    "bpm": {
                        "type": "integer",
                        "description": "BPM do metrônomo."
                    }
                },
                "required": ["bpm"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "contar_entrada",
            "description": "Adicionar contagem de entrada antes de tocar.",
            "parameters": {
                "type": "object",
                "properties": {
                    "barras": {
                        "type": "integer",
                        "description": "Número de barras para a contagem de entrada."
                    }
                },
                "required": ["barras"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "gravar_tomada",
            "description": "Começar a gravar a performance.",
            "parameters": {
                "type": "object",
                "properties": {},
                "required": []
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "parar_gravacao",
            "description": "Parar a gravação atual, quando o usuário disser o comando abaixo:",
            "parameters": {
                "type": "object",
                "properties": {},
                "required": []
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "comparar_tomadas",
            "description": "Comparar várias gravações.",
            "parameters": {
                "type": "object",
                "properties": {},
                "required": []
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "transpor_para_cima",
            "description": "Transpor para cima em 1 semitom.",
            "parameters": {
                "type": "object",
                "properties": {
                    "semitons_positivos": {
                        "type": "integer",
                        "description": "Número de semitons para transpor para cima."
                    }
                },
                "required": ["semitons_positivos"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "transpor_para_baixo",
            "description": "Transpor para baixo em 1 semitom.",
            "parameters": {
                "type": "object",
                "properties": {
                    "semitons_negativos": {
                        "type": "integer",
                        "description": "Número de semitons para transpor para baixo."
                    }
                },
                "required": ["semitons_negativos"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "transpor_para_cima_um_passo_inteiro",
            "description": "Transpor para cima em 2 semitons.",
            "parameters": {
                "type": "object",
                "properties": {
                    "semitons_positivos": {
                        "type": "integer",
                        "description": "Número de semitons para transpor para cima."
                    }
                },
                "required": ["semitons_positivos"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "transpor_para_baixo_um_passo_inteiro",
            "description": "Transpor para baixo em 2 semitons.",
            "parameters": {
                "type": "object",
                "properties": {
                    "semitons_negativos": {
                        "type": "integer",
                        "description": "Número de semitons para transpor para baixo."
                    }
                },
                "required": ["semitons_negativos"]
            }
        }
    },
    
]

# %% [markdown]
# ## setup

# %%
from dotenv import load_dotenv
load_dotenv()

import os

from openai import OpenAI

# model setup
openai = OpenAI(api_key=os.getenv('OPENAI_API'))

# %% [markdown]
# ### test

# %%
# basic test
openai_hello_answer = openai.chat.completions.create(
        model="gpt-4o",
        messages=[{
            "role": "user", 
            "content": 'oi',
            }],
        tools=moises_fns_openai_pt,
    )

if openai_hello_answer.choices[0].message.content:
    print(openai_hello_answer.choices[0].message.content)
else:
    print([(chat.function.name, chat.function.arguments) for chat in openai_hello_answer.choices[0].message.tool_calls])
# Out:
# Olá! Como posso ajudar você hoje?

# %% [markdown]
# ## invoke

# %%
import time
# invoke openai
# @retry(stop=stop_after_attempt(10), wait=wait_exponential(multiplier=1, min=4, max=10))
def invoke_openai(text, lang):
    iteration_timing = None
    start_timing = time.time()
    openai_response = openai.chat.completions.create(
        model="gpt-4o",
        messages=[{"role": "user", "content": text}],
        tools=moises_fns_openai_en if lang == 'en' else moises_fns_openai_pt,
    )
    end_timing = time.time()
    iteration_timing = end_timing - start_timing
    url = r'C:\Users\julio\Desktop\dev\artificial-intelligence\projects\function_calling\assets\data\processed\model_prompt\openai\openai_response_pt.txt'
    with open(url, 'a') as file:
        file.write(f"\ndata: {time.strftime('%Y-%m-%d %H:%M:%S', time.localtime())}\n")
        file.write(f"prompt: {text}\n")
        print('START----')
        try:
            functions = []
            if openai_response.choices[0].message.content == None:
                for block in openai_response.choices[0].message.tool_calls:
                    funtion = block.function
                    file.write(f"function: {funtion}\n")
                    file.write("-----------------------------------")
                    print(f"openai fn: {funtion}")
                    functions.append(funtion.name)
            else:
                text = openai_response.choices[0].message.content
                file.write(f"text: {text}\n")
                file.write("-----------------------------------")
                print(f"openai say: {text}")
            print('EXIT----')
            return functions, iteration_timing
        except TypeError as e:
            file.write(f"TypeError: {e}\n")
            file.write("-----------------------------------")
            return [], iteration_timing
        except Exception as e:
            file.write(f"Unexpected error: {e}\n")
            file.write("-----------------------------------")
            return [], iteration_timing

# %% [markdown]
# ### test

# %%
invoke_openai('iniciar minha festa!', 'en')
# Out:
# START----
# openai fn: Function(arguments='{}', name='play')
# EXIT----
# (['play'], 0.9342694282531738)

# %%
invoke_openai('iniciar minha festa!', 'pt')
# Out:
# START----
# openai fn: Function(arguments='{}', name='tocar')
# EXIT----
# (['tocar'], 0.7095093727111816)

# %% [markdown]
# # CLAUDE
#
# nao aceita sobrecarga mas aceita nivel de complexidade alta quanto (gpt) ou talvez mais alta, enquanto openai aceita. tolerancia a falha, so que eh o modelo que demora mais, claude lida melhor com subjetividade por isso talvez demora mais pra responder pois "raciocina mais"

# %% [markdown]
# ## fns en

# %%
moises_fns_claude_en = [
        {
    "name": "play",
    "description": "Start playback of the current track from where the seekbar is positioned. This is one of the most common intents used for initiating music playback.",
    "input_schema": {
        "type": "object",
        "properties": {},
        "required": []
    }
    },
        {
    "name": "pause",
    "description": "Pause the currently playing music track. This intent stops playback while maintaining the current position in the track.",
    "input_schema": {
        "type": "object",
        "properties": {},
        "required": []
    }
    },
        {
    "name": "from_the_top",
    "description": "Restart the current track from its beginning without pausing. This command automatically repositions the seekbar to the start of the song.",
    "input_schema": {
        "type": "object",
        "properties": {},
        "required": []
    }
    },
        {
    "name": "go_back",
    "description": "Rewind the current track by a preset interval. This intent moves the seekbar to an earlier point in the song.",
    "input_schema": {
        "type": "object",
        "properties": {
        "seconds": {
            "type": "integer",
            "description": "Number of seconds to rewind."
        }
        },
        "required": ["seconds"]
    }
    },
        {
    "name": "skip_ahead",
    "description": "Advance the playback by a specified interval or jump to a later point in the track. This intent moves the seekbar forward within the current song.",
    "input_schema": {
        "type": "object",
        "properties": {
        "seconds": {
            "type": "integer",
            "description": "Number of seconds to skip ahead."
        }
        },
        "required": ["seconds"]
    }
    },
        {
    "name": "slow_down",
    "description": "Decrease the playback speed. This command reduces the tempo in BPMs.",
    "input_schema": {
        "type": "object",
        "properties": {
        "bpm": {
            "type": "integer",
            "description": "Number of BPMs to reduce from the current tempo."
        }
        },
        "required": ["bpm"]
    }
    },
        {
    "name": "slow_down_a_lot",
    "description": "Decrease the playback speed. This command reduces the tempo in BPMs dramatically.",
    "input_schema": {
        "type": "object",
        "properties": {
        "bpm": {
            "type": "integer",
            "description": "Number of BPMs to reduce from the current tempo."
        }
        },
        "required": ["bpm"]
    }
    },
        {
    "name": "half_speed",
    "description": "Decrease the playback speed. This command reduces the tempo in BPMs dramatically to half of the tempo.",
    "input_schema": {
        "type": "object",
        "properties": {},
        "required": []
    }
    },
        {
    "name": "speed_up",
    "description": "Increase the playback speed. This intent accelerates the tempo.",
    "input_schema": {
        "type": "object",
        "properties": {
        "bpm": {
            "type": "integer",
            "description": "Number of BPMs to increase from the current tempo."
        }
        },
        "required": ["bpm"]
    }
    },
        {
    "name": "normal_speed",
    "description": "Reset the tempo to its original BPM.",
    "input_schema": {
        "type": "object",
        "properties": {},
        "required": []
    }
    },
        {
    "name": "set_tempo_by_percent",
    "description": "Set tempo to a specific user speed setting.",
    "input_schema": {
        "type": "object",
        "properties": {
        "percentage": {
            "type": "integer",
            "description": "Percentage of the original tempo to set."
        }
        },
        "required": ["percentage"]
    }
    },
        {
    "name": "set_tempo_by_bpm",
    "description": "Set tempo to a specific BPM requested by the user.",
    "input_schema": {
        "type": "object",
        "properties": {
        "bpm": {
            "type": "integer",
            "description": "Specific BPM to set."
        }
        },
        "required": ["bpm"]
    }
    },
        {
    "name": "loop_this_section",
    "description": "Activate loop on the current section.",
    "input_schema": {
        "type": "object",
        "properties": {
        "startTime": {
            "type": "integer",
            "description": "Start time of the section in seconds."
        },
        "endTime": {
            "type": "integer",
            "description": "End time of the section in seconds."
        }
        },
        "required": ["startTime", "endTime"]
    }
    },
        {
    "name": "go_to_chorus",
    "description": "Seek forward to the nearest chorus.",
    "input_schema": {
        "type": "object",
        "properties": {
        "sectionName": {
            "type": "string",
            "description": "Name of the chorus section."
        }
        },
        "required": ["sectionName"]
    }
    },
        {
    "name": "go_to_verse",
    "description": "Seek forward to the nearest verse.",
    "input_schema": {
        "type": "object",
        "properties": {
        "sectionName": {
            "type": "string",
            "description": "Name of the verse section."
        }
        },
        "required": ["sectionName"]
    }
    },
        {
    "name": "go_to_solo",
    "description": "Seek forward to the nearest solo.",
    "input_schema": {
        "type": "object",
        "properties": {
        "sectionName": {
            "type": "string",
            "description": "Name of the solo section."
        }
        },
        "required": ["sectionName"]
    }
    },
        {
    "name": "loop_the_chorus",
    "description": "Loop the marked chorus section.",
    "input_schema": {
        "type": "object",
        "properties": {
        "sectionName": {
            "type": "string",
            "description": "Name of the chorus section."
        }
        },
        "required": ["sectionName"]
    }
    },
        {
    "name": "loop_the_verse",
    "description": "Loop the marked verse section.",
    "input_schema": {
        "type": "object",
        "properties": {
        "sectionName": {
            "type": "string",
            "description": "Name of the verse section."
        }
        },
        "required": ["sectionName"]
    }
    },
        {
    "name": "loop_the_solo",
    "description": "Loop the marked solo section.",
    "input_schema": {
        "type": "object",
        "properties": {
        "sectionName": {
            "type": "string",
            "description": "Name of the solo section."
        }
        },
        "required": ["sectionName"]
    }
    },
        {
    "name": "clear_loop",
    "description": "Remove active loop.",
    "input_schema": {
        "type": "object",
        "properties": {},
        "required": []
    }
    },
        {
    "name": "isolate_vocals",
    "description": "Focus on the vocal part by muting all other tracks.",
    "input_schema": {
        "type": "object",
        "properties": {
        "stemType": {
            "type": "string",
            "description": "Type of stem to isolate (e.g., 'vocals')."
        }
        },
        "required": ["stemType"]
    }
    },
        {
    "name": "isolate_guitar",
    "description": "Focus on the guitar part by muting all other tracks.",
    "input_schema": {
        "type": "object",
        "properties": {
        "stemType": {
            "type": "string",
            "description": "Type of stem to isolate (e.g., 'guitar')."
        }
        },
        "required": ["stemType"]
    }
    },
        {
    "name": "isolate_bass",
    "description": "Focus on the bass part by muting all other tracks.",
    "input_schema": {
        "type": "object",
        "properties": {
        "stemType": {
            "type": "string",
            "description": "Type of stem to isolate (e.g., 'bass')."
        }
        },
        "required": ["stemType"]
    }
    },
        {
    "name": "isolate_drums",
    "description": "Focus on the drum part by muting all other tracks.",
    "input_schema": {
        "type": "object",
        "properties": {
        "stemType": {
            "type": "string",
            "description": "Type of stem to isolate (e.g., 'drums')."
        }
        },
        "required": ["stemType"]
    }
    },
        {
    "name": "isolate_piano",
    "description": "Focus on the piano part by muting all other tracks.",
    "input_schema": {
        "type": "object",
        "properties": {
        "stemType": {
            "type": "string",
            "description": "Type of stem to isolate (e.g., 'piano')."
        }
        },
        "required": ["stemType"]
    }
    },
        {
    "name": "remove_vocals",
    "description": "Mute the vocal track, keeping all other tracks unchanged.",
    "input_schema": {
        "type": "object",
        "properties": {
        "stemType": {
            "type": "string",
            "description": "Type of stem to mute (e.g., 'vocals')."
        }
        },
        "required": ["stemType"]
    }
    },
        {
    "name": "turn_down_drums",
    "description": "Reduce the drum track volume by a specified amount.",
    "input_schema": {
        "type": "object",
        "properties": {
        "stemType": {
            "type": "string",
            "description": "Type of stem to adjust (e.g., 'drums')."
        },
        "volume": {
            "type": "integer",
            "description": "Amount to reduce the volume by."
        }
        },
        "required": ["stemType", "volume"]
    }
    },
        {
    "name": "turn_up_bass",
    "description": "Increase the bass track volume by a specified amount.",
    "input_schema": {
        "type": "object",
        "properties": {
        "stemType": {
            "type": "string",
            "description": "Type of stem to adjust (e.g., 'bass')."
        },
        "volume": {
            "type": "integer",
            "description": "Amount to increase the volume by."
        }
        },
        "required": ["stemType", "volume"]
    }
    },
        {
    "name": "reset_mix",
    "description": "Reset all volumes from the mix back to the default volume of all tracks.",
    "input_schema": {
        "type": "object",
        "properties": {},
        "required": []
    }
    },
        {
    "name": "show_all_instruments",
    "description": "Unmute all instruments, keeping the current volume.",
    "input_schema": {
        "type": "object",
        "properties": {},
        "required": []
    }
    },
        {
    "name": "metronome_on",
    "description": "Enable the metronome.",
    "input_schema": {
        "type": "object",
        "properties": {},
        "required": []
    }
    },
        {
    "name": "metronome_off",
    "description": "Disable the metronome.",
    "input_schema": {
        "type": "object",
        "properties": {},
        "required": []
    }
    },
        {
    "name": "set_metronome_by_bpm",
    "description": "Set the metronome to a specific BPM.",
    "input_schema": {
        "type": "object",
        "properties": {
        "bpm": {
            "type": "integer",
            "description": "Specific BPM to set the metronome to."
        }
        },
        "required": ["bpm"]
    }
    },
        {
    "name": "count_in",
    "description": "Add a count-in before playing.",
    "input_schema": {
        "type": "object",
        "properties": {
        "bars": {
            "type": "integer",
            "description": "Number of bars for the count-in."
        }
        },
        "required": ["bars"]
    }
    },
        {
    "name": "record_take",
    "description": "Start recording a performance.",
    "input_schema": {
        "type": "object",
        "properties": {},
        "required": []
    }
    },
        {
    "name": "stop_recording",
    "description": "Stop the current recording.",
    "input_schema": {
        "type": "object",
        "properties": {},
        "required": []
    }
    },
        {
    "name": "compare_takes",
    "description": "Compare multiple recordings.",
    "input_schema": {
        "type": "object",
        "properties": {},
        "required": []
    }
    },
        {
    "name": "transpose_up",
    "description": "Transpose up by 1 semitone.",
    "input_schema": {
        "type": "object",
        "properties": {
        "positive_semitones": {
            "type": "integer",
            "description": "Number of semitones to transpose up."
        }
        },
        "required": ["positive_semitones"]
    }
    },
        {
    "name": "transpose_down",
    "description": "Transpose down by 1 semitone.",
    "input_schema": {
        "type": "object",
        "properties": {
        "negative_semitones": {
            "type": "integer",
            "description": "Number of semitones to transpose down."
        }
        },
        "required": ["negative_semitones"]
    }
    },
        {
    "name": "transpose_up_a_whole_step",
    "description": "Transpose up by 2 semitones.",
    "input_schema": {
        "type": "object",
        "properties": {
        "positive_semitones": {
            "type": "integer",
            "description": "Number of semitones to transpose up."
        }
        },
        "required": ["positive_semitones"]
    }
    },
        {
    "name": "transpose_down_a_whole_step",
    "description": "Transpose down by 2 semitones.",
    "input_schema": {
        "type": "object",
        "properties": {
        "negative_semitones": {
            "type": "integer",
            "description": "Number of semitones to transpose down."
        }
        },
        "required": ["negative_semitones"]
    }
    }
]

# %% [markdown]
# ## fns pt

# %%
moises_fns_claude_pt = [
    {
        "name": "reproduzir",
        "description": "Inicia a reprodução da faixa atual a partir da posição da barra de progresso. Este é um dos comandos mais comuns para iniciar a reprodução de música.",
        "input_schema": {
            "type": "object",
            "properties": {},
            "required": []
        }
    },
    {
        "name": "pausar",
        "description": "Pausa a faixa de música que está sendo reproduzida. Este comando interrompe a reprodução, mas mantém a posição atual na faixa.",
        "input_schema": {
            "type": "object",
            "properties": {},
            "required": []
        }
    },
    {
        "name": "do_inicio",
        "description": "Reinicia a faixa atual do começo sem pausar. Esse comando automaticamente reposiciona a barra de progresso no início da música. Se a faixa estiver pausada, ela é reiniciada e começa a tocar imediatamente.",
        "input_schema": {
            "type": "object",
            "properties": {},
            "required": []
        }
    },
    {
        "name": "voltar",
        "description": "Retrocede a faixa atual por um intervalo predefinido. Esse comando move a barra de progresso para um ponto anterior na música. Padrão: voltar 10 segundos.",
        "input_schema": {
            "type": "object",
            "properties": {
                "segundos": {
                    "type": "integer",
                    "description": "Numero de segundos para retroceder."
                }
            },
            "required": ["segundos"]
        }
    },
    {
        "name": "diminuir_ritmo",
        "description": "Diminui a velocidade de reprodução, reduzindo o tempo em BPMs. Padrão: reduzir -10 BPM do BPM atual.",
        "input_schema": {
            "type": "object",
            "properties": {
                "bpm": {
                    "type": "integer",
                    "description": "Quantidade de BPMs para diminuir."
                }
            },
            "required": ["bpm"]
        }
    },
    {
        "name": "diminuir_ritmo_muito",
        "description": "Diminui a velocidade de reprodução de forma mais intensa, reduzindo o tempo em BPMs. Padrão: reduzir -20 BPM do BPM atual.",
        "input_schema": {
            "type": "object",
            "properties": {
                "bpm": {
                    "type": "integer",
                    "description": "Quantidade de BPMs para diminuir."
                }
            },
            "required": ["bpm"]
        }
    },
    {
        "name": "metade_da_velocidade",
        "description": "Reduz a velocidade de reprodução drasticamente para metade do tempo. O BPM atual é reduzido pela metade.",
        "input_schema": {
            "type": "object",
            "properties": {},
            "required": []
        }
    },
    {
        "name": "acelerar",
        "description": "Aumenta a velocidade de reprodução, acelerando o tempo em BPMs. Padrão: aumentar +10 BPM do BPM atual.",
        "input_schema": {
            "type": "object",
            "properties": {
                "bpm": {
                    "type": "integer",
                    "description": "Quantidade de BPMs para aumentar."
                }
            },
            "required": ["bpm"]
        }
    },
        {
        "name": "tocar",
        "description": "Inicia a reprodução da faixa atual a partir da posição da barra de busca. Esse é um dos comandos mais comuns para iniciar a reprodução de música.",
        "input_schema": {
            "type": "object",
            "properties": {},
            "required": []
        }
    },
    {
        "name": "avancar",
        "description": "Avanca a reprodução em um intervalo definido ou pula para um ponto posterior na faixa. O padrão é avançar 10 segundos.",
        "input_schema": {
            "type": "object",
            "properties": {
                "segundos": {
                    "type": "integer",
                    "description": "Numero de segundos para avancar."
                }
            },
            "required": ["segundos"]
        }
    },
    {
        "name": "diminuir_velocidade",
        "description": "Diminui a velocidade de reprodução, reduzindo o tempo em BPMs. O padrão é reduzir 10 BPMs do tempo atual.",
        "input_schema": {
            "type": "object",
            "properties": {
                "bpm": {
                    "type": "integer",
                    "description": "Quantidade de BPMs para diminuir."
                }
            },
            "required": ["bpm"]
        }
    },
    {
        "name": "diminuir_muito",
        "description": "Diminui bastante a velocidade de reprodução, reduzindo o tempo em BPMs. O padrão é reduzir 20 BPMs do tempo atual.",
        "input_schema": {
            "type": "object",
            "properties": {
                "bpm": {
                    "type": "integer",
                    "description": "Quantidade de BPMs para diminuir."
                }
            },
            "required": ["bpm"]
        }
    },
    {
        "name": "velocidade_normal",
        "description": "Restaura o tempo original da música.",
        "input_schema": {
            "type": "object",
            "properties": {},
            "required": []
        }
    },
    {
        "name": "definir_tempo_por_porcentagem",
        "description": "Define o tempo para uma porcentagem específica escolhida pelo usuário.",
        "input_schema": {
            "type": "object",
            "properties": {
                "porcentagem": {
                    "type": "integer",
                    "description": "Porcentagem do tempo original."
                }
            },
            "required": ["porcentagem"]
        }
    },
    {
        "name": "definir_tempo_por_bpm",
        "description": "Define o tempo para um BPM específico escolhido pelo usuário.",
        "input_schema": {
            "type": "object",
            "properties": {
                "bpm": {
                    "type": "integer",
                    "description": "BPM desejado."
                }
            },
            "required": ["bpm"]
        }
    },
    {
    "name": "loopar_trecho",
    "description": "Ativa o loop em um trecho da música. Comandos: 'Loopar este trecho', 'Repetir esta parte', 'Ciclo aqui', 'De novo', 'Trecho em loop', 'Vamos praticar esse pedaço'.",
    "input_schema": {
      "type": "object",
      "properties": {
        "tempoInicio": {
          "type": "integer",
          "description": "Tempo de início do trecho em segundos."
        },
        "tempoFim": {
          "type": "integer",
          "description": "Tempo de fim do trecho em segundos."
        }
      },
      "required": ["tempoInicio", "tempoFim"]
    }
  },
  {
    "name": "ir_para_refrao",
    "description": "Avança para o refrão mais próximo. Comandos: 'Ir para o refrão', 'Pula para o refrão', 'Direto para o refrão', 'Vamos para a parte principal'.",
    "input_schema": {
      "type": "object",
      "properties": {
        "nomeSecao": {
          "type": "string",
          "description": "Nome da seção do refrão."
        }
      },
      "required": ["nomeSecao"]
    }
  },
  {
    "name": "ir_para_verso",
    "description": "Avança para o próximo verso. Comandos: 'Ir para o verso', 'Pula para a estrofe', 'Direto para o verso'.",
    "input_schema": {
      "type": "object",
      "properties": {
        "nomeSecao": {
          "type": "string",
          "description": "Nome da seção do verso."
        }
      },
      "required": ["nomeSecao"]
    }
  },
  {
    "name": "ir_para_solo",
    "description": "Avança para o solo mais próximo. Comandos: 'Ir para o solo', 'Pula para o solo', 'Vai para a parte instrumental'.",
    "input_schema": {
      "type": "object",
      "properties": {
        "nomeSecao": {
          "type": "string",
          "description": "Nome da seção do solo."
        }
      },
      "required": ["nomeSecao"]
    }
  },
  {
    "name": "loopar_refrao",
    "description": "Coloca o refrão em loop. Comandos: 'Loopar o refrão', 'Repetir o refrão', 'Ciclo no refrão', 'De novo o refrão'.",
    "input_schema": {
      "type": "object",
      "properties": {
        "nomeSecao": {
          "type": "string",
          "description": "Nome da seção do refrão."
        }
      },
      "required": ["nomeSecao"]
    }
  },
  {
    "name": "loopar_verso",
    "description": "Coloca o verso em loop. Comandos: 'Loopar o verso', 'Repetir o verso', 'Ciclo no verso', 'De novo o verso'.",
    "input_schema": {
      "type": "object",
      "properties": {
        "nomeSecao": {
          "type": "string",
          "description": "Nome da seção do verso."
        }
      },
      "required": ["nomeSecao"]
    }
  },
  {
    "name": "loopar_solo",
    "description": "Coloca o solo em loop. Comandos: 'Loopar o solo', 'Repetir o solo', 'Ciclo no solo', 'De novo o solo'.",
    "input_schema": {
      "type": "object",
      "properties": {
        "nomeSecao": {
          "type": "string",
          "description": "Nome da seção do solo."
        }
      },
      "required": ["nomeSecao"]
    }
  },
  {
    "name": "limpar_loop",
    "description": "Remove o loop ativo. Comandos: 'Parar loop', 'Cancelar loop', 'Sem repetição', 'Reprodução linear'.",
    "input_schema": {
      "type": "object",
      "properties": {},
      "required": []
    }
  },
  {
    "name": "isolar_vocais",
    "description": "Focar na parte vocal. Comandos (O primeiro comando é geralmente o mais comum): 'Isolar vocais', 'Só os vocais', 'Vocais em destaque', 'Apenas o cantor', 'Me dê o vocalista', 'Extrair os vocais', 'Vocal principal apenas', 'Reduzir para vocais'.",
    "input_schema": {
      "type": "object",
      "properties": {
        "tipo_de_stem": {
          "type": "string",
          "description": "Tipo de stem a ser isolado."
        }
      },
      "required": ["tipo_de_stem"]
    }
  },
  {
    "name": "isolar_guitarra",
    "description": "Solo de guitarra silenciando todas as outras faixas. Focar na parte da guitarra. Comandos (O primeiro comando é geralmente o mais comum): 'Isolar guitarra', 'Só o machado', 'Guitarra apenas', 'Seis cordas apenas', 'Extrair a guitarra', 'Cordas apenas', 'Guit apenas', 'Deixe-me ouvir a guitarra'.",
    "input_schema": {
      "type": "object",
      "properties": {
        "tipo_de_stem": {
          "type": "string",
          "description": "Tipo de stem a ser isolado."
        }
      },
      "required": ["tipo_de_stem"]
    }
  },
  {
    "name": "isolar_baixo",
    "description": "Solo de baixo silenciando todas as outras faixas. Focar na parte do baixo. Comandos (O primeiro comando é geralmente o mais comum): 'Isolar baixo', 'Só os graves', 'Baixo apenas', 'Graves apenas', 'Extrair o baixo', 'Graves apenas', 'Deixe-me ouvir o que está caminhando', 'Só o groove'.",
    "input_schema": {
      "type": "object",
      "properties": {
        "tipo_de_stem": {
          "type": "string",
          "description": "Tipo de stem a ser isolado."
        }
      },
      "required": ["tipo_de_stem"]
    }
  },
  {
    "name": "isolar_bateria",
    "description": "Solo de bateria silenciando todas as outras faixas. Focar na parte da bateria. Comandos (O primeiro comando é geralmente o mais comum): 'Isolar bateria', 'Só o kit', 'Bateria apenas', 'Peles apenas', 'Extrair a batida', 'Percussão apenas', 'Seção rítmica', 'Batida apenas'.",
    "input_schema": {
      "type": "object",
      "properties": {
        "tipo_de_stem": {
          "type": "string",
          "description": "Tipo de stem a ser isolado."
        }
      },
      "required": ["tipo_de_stem"]
    }
  },
  {
    "name": "isolar_piano",
    "description": "Solo de piano silenciando todas as outras faixas. Se houver faixas de piano e teclados, silenciar apenas o piano, deixando os teclados mudos. Focar na parte do piano. Comandos (O primeiro comando é geralmente o mais comum): 'Isolar piano', 'Só os teclados', 'Piano apenas', 'Marfins apenas', 'Extrair os teclados', 'Teclados apenas', 'Deixe-me ouvir o piano', 'Só os acordes de acompanhamento'.",
    "input_schema": {
      "type": "object",
      "properties": {
        "tipo_de_stem": {
          "type": "string",
          "description": "Tipo de stem a ser isolado."
        }
      },
      "required": ["tipo_de_stem"]
    }
  },
  {
    "name": "remover_vocais",
    "description": "Silenciar a faixa vocal, mantendo todas as outras faixas inalteradas. Para prática vocal com acompanhamento. Comandos (O primeiro comando é geralmente o mais comum): 'Remover vocais', 'Tirar os vocais', 'Faixa de rascunho', 'Acompanhamento apenas', 'Tirar o cantor', 'Faixa apenas', 'Menos um', 'Modo karaokê'.",
    "input_schema": {
      "type": "object",
      "properties": {
        "tipo_de_stem": {
          "type": "string",
          "description": "Tipo de stem a ser silenciado."
        }
      },
      "required": ["tipo_de_stem"]
    }
  },
  {
    "name": "abaixar_bateria",
    "description": "Alterar o volume da faixa de bateria. Reduzir o volume da bateria em incrementos de um número específico. Comandos (O primeiro comando é geralmente o mais comum): 'Abaixar bateria', 'Diminuir o kit', 'Enterrar um pouco a bateria', 'Bateria no fundo', 'Menos batida', 'Leve nas peles', 'Recuar a batida', 'Bateria muito alta'.",
    "input_schema": {
      "type": "object",
      "properties": {
        "tipo_de_stem": {
          "type": "string",
          "description": "Tipo de stem da bateria."
        },
        "volume": {
          "type": "integer",
          "description": "Quantidade de volume para diminuir."
        }
      },
      "required": ["tipo_de_stem", "volume"]
    }
  },
  {
    "name": "aumentar_baixo",
    "description": "Alterar o volume da faixa de baixo. Aumentar o volume do baixo em incrementos de um número específico. Comandos (O primeiro comando é geralmente o mais comum): 'Aumentar baixo', 'Mais graves', 'Bombear o baixo', 'Engrossar os graves', 'Baixo na cara', 'Engordar os graves', 'Me dê mais groove', 'Aumentar a batida'.",
    "input_schema": {
      "type": "object",
      "properties": {
        "tipo_de_stem": {
          "type": "string",
          "description": "Tipo de stem do baixo."
        },
        "volume": {
          "type": "integer",
          "description": "Quantidade de volume para aumentar."
        }
      },
      "required": ["tipo_de_stem", "volume"]
    }
  },
  {
    "name": "resetar_mixagem",
    "description": "Redefinir todos os volumes da mixagem para o volume padrão de todas as faixas. Redefinir todos os volumes de stem. Comandos (O primeiro comando é geralmente o mais comum): 'Resetar mixagem', 'Aplanar os faders', 'Voltar para a mesa', 'Zerar a mixagem', 'Equilíbrio padrão', 'Nivelar a mixagem', 'Redefinir o equilíbrio', 'Posição inicial'.",
    "input_schema": {
      "type": "object",
      "properties": {},
      "required": []
    }
  },
  {
    "name": "mostrar_todos_instrumentos",
    "description": "Desmutar todos os instrumentos, mantendo o volume atual. Mostrar todos os stems de instrumentos. Comandos (O primeiro comando é geralmente o mais comum): 'Mostrar todos os instrumentos', 'Banda completa', 'Tudo dentro', 'Todos os músicos', 'Mixagem completa', 'Trazer tudo de volta', 'Empilhar tudo', 'Conjunto completo'.",
    "input_schema": {
      "type": "object",
      "properties": {},
      "required": []
    }
  },
  {
    "name": "metronomo_ligado",
    "description": "Ativar o metrônomo. Comandos (O primeiro comando é geralmente o mais comum): 'Metrônomo ligado', 'Clique de tempo', 'Me dê o clique', 'Clique dentro', 'Me dê um tempo', 'Soltar o metrônomo', 'Marcador de batida', 'Marcador de tempo'.",
    "input_schema": {
      "type": "object",
      "properties": {},
      "required": []
    }
  },
  {
    "name": "metronomo_desligado",
    "description": "Desativar o metrônomo. Comandos (O primeiro comando é geralmente o mais comum): 'Metrônomo desligado', 'Matar o clique', 'Sem clique', 'Clique fora', 'Descartar o metrônomo', 'Tempo livre', 'Fora da grade', 'Sem mais tic-tac'.",
    "input_schema": {
      "type": "object",
      "properties": {},
      "required": []
    }
  },
  {
    "name": "definir_metronomo_por_bpm",
    "description": "Definir o tempo específico do metrônomo. Comandos (O primeiro comando é geralmente o mais comum): 'Definir metrônomo para número específico', 'Clique em número específico', 'Tempo número específico', 'número específico no dial', 'Marcar em número específico', 'Semibreve = número específico', 'número específico de cliques', 'número específico no metrônomo'.",
    "input_schema": {
      "type": "object",
      "properties": {
        "bpm": {
          "type": "integer",
          "description": "BPM do metrônomo."
        }
      },
      "required": ["bpm"]
    }
  },
  {
    "name": "contar_entrada",
    "description": "Adicionar contagem de entrada antes de tocar. Comandos (O primeiro comando é geralmente o mais comum): 'Contar entrada', 'Me contar', 'Me dê quatro', 'Contar', 'Me lançar', 'Quatro cliques de entrada', 'Contagem de introdução', 'Me clicar'.",
    "input_schema": {
      "type": "object",
      "properties": {
        "barras": {
          "type": "integer",
          "description": "Número de barras para a contagem de entrada."
        }
      },
      "required": ["barras"]
    }
  },
  {
    "name": "gravar_tomada",
    "description": "Começar a gravar a performance. Comandos (O primeiro comando é geralmente o mais comum): 'Gravar tomada', 'Registrar', 'Gravar isso', 'Soltar uma tomada', 'Capturar isso', 'Apertar gravar', 'Pegar isso', 'Gravar isso na fita', 'Faixa isso'.",
    "input_schema": {
      "type": "object",
      "properties": {},
      "required": []
    }
  },
  {
    "name": "parar_gravacao",
    "description": "Parar a gravação atual, quando o usuário disser o comando abaixo: Comandos (O primeiro comando é geralmente o mais comum): 'Parar gravação', 'Essa é uma tomada', 'Cortar a fita', 'Entendi', 'Na lata', 'Essa é a certa', 'Imprimir isso', 'Fim da tomada', 'Isso é um encerramento'.",
    "input_schema": {
      "type": "object",
      "properties": {},
      "required": []
    }
  },
  {
    "name": "comparar_tomadas",
    "description": "Comparar várias gravações. Comandos (O primeiro comando é geralmente o mais comum): 'Comparar tomadas', 'Vamos ouvir as tomadas', 'A/B elas', 'Qual é a melhor', 'Tocar as opções', 'Verificação de tomada', 'Executar as versões', 'Vamos ouvir o que temos'.",
    "input_schema": {
      "type": "object",
      "properties": {},
      "required": []
    }
  },
  {
    "name": "transpor_para_cima",
    "description": "Transpor para cima em 1 semitom. Comandos (O primeiro comando é geralmente o mais comum): 'Transpor para cima', 'Aumentar', 'Aumentar meio tom', 'Subir um semi', 'Subir', 'Empurrar para cima', 'Ajustar para cima', 'Meio passo para cima'.",
    "input_schema": {
      "type": "object",
      "properties": {
        "semitons_positivos": {
          "type": "integer",
          "description": "Número de semitons para transpor para cima."
        }
      },
      "required": ["semitons_positivos"]
    }
  },
  {
    "name": "transpor_para_baixo",
    "description": "Transpor para baixo em 1 semitom. Comandos (O primeiro comando é geralmente o mais comum): 'Transpor para baixo', 'Diminuir', 'Diminuir meio tom', 'Descer um semi', 'Descer', 'Ajustar para baixo', 'Meio passo para baixo', 'Trazer para baixo'.",
    "input_schema": {
      "type": "object",
      "properties": {
        "semitons_negativos": {
          "type": "integer",
          "description": "Número de semitons para transpor para baixo."
        }
      },
      "required": ["semitons_negativos"]
    }
  },
  {
    "name": "transpor_para_cima_um_passo_inteiro",
    "description": "Transpor para cima em 2 semitons. Comandos (O primeiro comando é geralmente o mais comum): 'Transpor para cima um passo inteiro', 'Subir um tom', 'Passo inteiro para cima', 'Subir dois', 'Aumentar um inteiro', 'Subir dois trastes', 'Segunda maior para cima', 'Subir um passo inteiro'.",
    "input_schema": {
      "type": "object",
      "properties": {
        "semitons_positivos": {
          "type": "integer",
          "description": "Número de semitons para transpor para cima."
        }
      },
      "required": ["semitons_positivos"]
    }
  },
  {
    "name": "transpor_para_baixo_um_passo_inteiro",
    "description": "Transpor para baixo em 2 semitons. Comandos (O primeiro comando é geralmente o mais comum): 'Transpor para baixo um passo inteiro', 'Descer um tom', 'Passo inteiro para baixo', 'Descer dois', 'Diminuir um inteiro', 'Descer dois trastes', 'Segunda maior para baixo', 'Descer um passo inteiro'.",
    "input_schema": {
      "type": "object",
      "properties": {
        "semitons_negativos": {
          "type": "integer",
          "description": "Número de semitons para transpor para baixo."
        }
      },
      "required": ["semitons_negativos"]
    }
  }
]

# %% [markdown]
# ## api

# %%
import anthropic

# model setup
claude = anthropic.Client(api_key=os.getenv('CLAUDE_API'))

# %% [markdown]
# ### test

# %%
# basic test
claude_hello_answer = claude.messages.create(
    model='claude-3-7-sonnet-20250219',
    messages=[{
        'role': 'user',
        'content': 'oi'
    }],
    max_tokens=4096,
    tools=moises_fns_claude_pt
)

for fn in claude_hello_answer.content:
    if fn.type == 'tool_use':
        print(fn.name, fn.input)
    else:
        print(fn.text)
# [(fn.name, fn.input) if fn.type == 'tool_use' else fn.text for fn in claude_hello_answer.content]
# Out:
# Olá! Como posso ajudar você hoje com relação à reprodução ou edição de música? Posso auxiliar com comandos como reproduzir, pausar, ajustar velocidade, isolar instrumentos, entre outros. O que você gostaria de fazer?

# %% [markdown]
# ## invoke

# %%
# invoke claude
# @retry(stop=stop_after_attempt(10), wait=wait_exponential(multiplier=1, min=4, max=10))
def invoke_claude(text, lang):
    iteration_timing = None
    start_timing = time.time()
    claude_response = claude.messages.create(
        model='claude-3-7-sonnet-20250219',
        messages=[{
            'role': 'user',
            'content': text
        }],
        max_tokens=4096,
        tools=moises_fns_claude_en if lang == 'en' else moises_fns_claude_pt
    )
    end_timing = time.time()
    iteration_timing = end_timing - start_timing
    url = r'C:\Users\julio\Desktop\dev\artificial-intelligence\projects\function_calling\assets\data\processed\model_prompt\claude\claude_response_pt.txt'
    with open(url, 'a') as file:
        file.write(f"\ndata: {time.strftime('%Y-%m-%d %H:%M:%S', time.localtime())}\n")
        file.write(f"prompt: {text}\n")
        print('START----')
        try:
            functions = []
            for block in claude_response.content:
                if block.type == 'tool_use':
                    function = block
                    file.write(f"function: {function}\n")
                    file.write("-----------------------------------")
                    print(f"claude fn: {function}")
                    functions.append(function.name)
                else:
                    text = block.text
                    file.write(f"text: {text}\n")
                    file.write("-----------------------------------")
                    print(f"claude say: {text}")
            print('EXIT----')
            return functions, iteration_timing
        except TypeError as e:
            file.write(f"TypeError: {e}\n")
            file.write("-----------------------------------")
            return [], iteration_timing
        except Exception as e:
            file.write(f"Unexpected error: {e}\n")
            file.write("-----------------------------------")
            return [], iteration_timing

# %% [markdown]
# ### test

# %%
invoke_claude('iniciar minha festa!', 'en')
# Out:
# START----
# claude say: Parece que você gostaria de iniciar a reprodução de música para sua festa. Posso ajudar com isso!
#
# Vou iniciar a reprodução da música atual para você.
# claude fn: ToolUseBlock(id='toolu_01EM3sCaCEwNGn9eTDeccuDW', input={}, name='play', type='tool_use')
# EXIT----
# (['play'], 1.8973491191864014)

# %%
invoke_claude('iniciar minha festa!', 'pt')
# Out:
# START----
# claude say: Para iniciar sua festa, vou reproduzir a música atual. Vamos começar!
# claude fn: ToolUseBlock(id='toolu_015cs8GSEwPYwjhP7zgDgvp1', input={}, name='reproduzir', type='tool_use')
# EXIT----
# (['reproduzir'], 2.3573153018951416)

# %% [markdown]
# # GEMINI
#
# simples, rapido porem objetivo, nao pode consegue processar comandos mais complexos (enquanto gpt e claude pode)  como traducao, textos subjetivos, etc

# %% [markdown]
# ## api

# %%
from google import genai
from google.genai import types

# model setup for below fns call action
gemini = genai.Client(api_key=os.getenv('GEMINI_API'))

# %% [markdown]
# ## fns en

# %%
# functions setup v2.2
fn_play = types.FunctionDeclaration.from_callable(callable=play, client=gemini)
fn_play = types.FunctionDeclaration.from_callable(callable=play, client=gemini)
fn_pause = types.FunctionDeclaration.from_callable(callable=pause, client=gemini)
fn_from_the_top = types.FunctionDeclaration.from_callable(callable=from_the_top, client=gemini)
fn_go_back = types.FunctionDeclaration.from_callable(callable=go_back, client=gemini)
fn_skip_ahead = types.FunctionDeclaration.from_callable(callable=skip_ahead, client=gemini)
fn_slow_down = types.FunctionDeclaration.from_callable(callable=slow_down, client=gemini)
fn_slow_down_a_lot = types.FunctionDeclaration.from_callable(callable=slow_down_a_lot, client=gemini)
fn_half_speed = types.FunctionDeclaration.from_callable(callable=half_speed, client=gemini)
fn_speed_up = types.FunctionDeclaration.from_callable(callable=speed_up, client=gemini)
fn_normal_speed = types.FunctionDeclaration.from_callable(callable=normal_speed, client=gemini)
fn_set_tempo_by_percent = types.FunctionDeclaration.from_callable(callable=set_tempo_by_percent, client=gemini)
fn_set_tempo_by_bpm = types.FunctionDeclaration.from_callable(callable=set_tempo_by_bpm, client=gemini)
fn_loop_this_section = types.FunctionDeclaration.from_callable(callable=loop_this_section, client=gemini)
fn_go_to_chorus = types.FunctionDeclaration.from_callable(callable=go_to_chorus, client=gemini)
fn_go_to_verse = types.FunctionDeclaration.from_callable(callable=go_to_verse, client=gemini)
fn_go_to_solo = types.FunctionDeclaration.from_callable(callable=go_to_solo, client=gemini)
fn_loop_the_chorus = types.FunctionDeclaration.from_callable(callable=loop_the_chorus, client=gemini)
fn_loop_the_verse = types.FunctionDeclaration.from_callable(callable=loop_the_verse, client=gemini)
fn_loop_the_solo = types.FunctionDeclaration.from_callable(callable=loop_the_solo, client=gemini)
fn_clear_loop = types.FunctionDeclaration.from_callable(callable=clear_loop, client=gemini)
fn_isolate_vocals = types.FunctionDeclaration.from_callable(callable=isolate_vocals, client=gemini)
fn_isolate_guitar = types.FunctionDeclaration.from_callable(callable=isolate_guitar, client=gemini)
fn_isolate_bass = types.FunctionDeclaration.from_callable(callable=isolate_bass, client=gemini)
fn_isolate_drums = types.FunctionDeclaration.from_callable(callable=isolate_drums, client=gemini)
fn_isolate_piano = types.FunctionDeclaration.from_callable(callable=isolate_piano, client=gemini)
fn_remove_vocals = types.FunctionDeclaration.from_callable(callable=remove_vocals, client=gemini)
fn_turn_down_drums = types.FunctionDeclaration.from_callable(callable=turn_down_drums, client=gemini)
fn_turn_up_bass = types.FunctionDeclaration.from_callable(callable=turn_up_bass, client=gemini)
fn_reset_mix = types.FunctionDeclaration.from_callable(callable=reset_mix, client=gemini)
fn_show_all_instruments = types.FunctionDeclaration.from_callable(callable=show_all_instruments, client=gemini)
fn_metronome_on = types.FunctionDeclaration.from_callable(callable=metronome_on, client=gemini)
fn_metronome_off = types.FunctionDeclaration.from_callable(callable=metronome_off, client=gemini)
fn_set_metronome_by_bpm = types.FunctionDeclaration.from_callable(callable=set_metronome_by_bpm, client=gemini)
fn_count_in = types.FunctionDeclaration.from_callable(callable=count_in, client=gemini)
fn_record_take = types.FunctionDeclaration.from_callable(callable=record_take, client=gemini)
fn_stop_recording = types.FunctionDeclaration.from_callable(callable=stop_recording, client=gemini)
fn_compare_takes = types.FunctionDeclaration.from_callable(callable=compare_takes, client=gemini)
fn_transpose_up = types.FunctionDeclaration.from_callable(callable=transpose_up, client=gemini)
fn_transpose_down = types.FunctionDeclaration.from_callable(callable=transpose_down, client=gemini)
fn_transpose_up_a_whole_step = types.FunctionDeclaration.from_callable(callable=transpose_up_a_whole_step, client=gemini)
fn_transpose_down_a_whole_step = types.FunctionDeclaration.from_callable(callable=transpose_down_a_whole_step, client=gemini)

# %%
moises_fns_gemini_en = [
    fn_play,
    fn_pause,
    fn_from_the_top,
    fn_go_back,
    fn_skip_ahead,
    fn_slow_down,
    fn_slow_down_a_lot,
    fn_half_speed,
    fn_speed_up,
    fn_normal_speed,
    fn_set_tempo_by_percent,
    fn_set_tempo_by_bpm,
    fn_loop_this_section,
    fn_go_to_chorus,
    fn_go_to_verse,
    fn_go_to_solo,
    fn_loop_the_chorus,
    fn_loop_the_verse,
    fn_loop_the_solo,
    fn_clear_loop,
    fn_isolate_vocals,
    fn_isolate_guitar,
    fn_isolate_bass,
    fn_isolate_drums,
    fn_isolate_piano,
    fn_remove_vocals,
    fn_turn_down_drums,
    fn_turn_up_bass,
    fn_reset_mix,
    fn_show_all_instruments,
    fn_metronome_on,
    fn_metronome_off,
    fn_set_metronome_by_bpm,
    fn_count_in,
    fn_record_take,
    fn_stop_recording,
    fn_compare_takes,
    fn_transpose_up,
    fn_transpose_down,
    fn_transpose_up_a_whole_step,
    fn_transpose_down_a_whole_step,
]

# %% [markdown]
# ## fns pt

# %%
# functions setup v2.2
fn_play = types.FunctionDeclaration.from_callable(callable=reproduzir, client=gemini)
fn_pausar = types.FunctionDeclaration.from_callable(callable=pausar, client=gemini)
fn_do_inicio = types.FunctionDeclaration.from_callable(callable=do_inicio, client=gemini)
fn_voltar = types.FunctionDeclaration.from_callable(callable=voltar, client=gemini)
fn_avancar = types.FunctionDeclaration.from_callable(callable=avancar, client=gemini)
fn_diminuir_ritmo_muito = types.FunctionDeclaration.from_callable(callable=diminuir_ritmo_muito, client=gemini)
fn_metade_da_velocidade = types.FunctionDeclaration.from_callable(callable=metade_da_velocidade, client=gemini)
fn_acelerar = types.FunctionDeclaration.from_callable(callable=acelerar, client=gemini)
fn_tocar = types.FunctionDeclaration.from_callable(callable=tocar, client=gemini)
fn_diminuir_velocidade = types.FunctionDeclaration.from_callable(callable=diminuir_velocidade, client=gemini)
fn_diminuir_muito = types.FunctionDeclaration.from_callable(callable=diminuir_muito, client=gemini)
fn_velocidade_normal = types.FunctionDeclaration.from_callable(callable=velocidade_normal, client=gemini)
fn_definir_tempo_por_porcentagem = types.FunctionDeclaration.from_callable(callable=definir_tempo_por_porcentagem, client=gemini)
fn_definir_tempo_por_bpm = types.FunctionDeclaration.from_callable(callable=definir_tempo_por_bpm, client=gemini)
fn_loopar_trecho = types.FunctionDeclaration.from_callable(callable=loopar_trecho, client=gemini)
fn_ir_para_refrao = types.FunctionDeclaration.from_callable(callable=ir_para_refrao, client=gemini)
fn_ir_para_verso = types.FunctionDeclaration.from_callable(callable=ir_para_verso, client=gemini)
fn_ir_para_solo = types.FunctionDeclaration.from_callable(callable=ir_para_solo, client=gemini)
fn_loopar_refrao = types.FunctionDeclaration.from_callable(callable=loopar_refrao, client=gemini)
fn_loopar_verso = types.FunctionDeclaration.from_callable(callable=loopar_verso, client=gemini)
fn_loopar_solo = types.FunctionDeclaration.from_callable(callable=loopar_solo, client=gemini)
fn_limpar_loop = types.FunctionDeclaration.from_callable(callable=limpar_loop, client=gemini)
fn_isolar_vocais = types.FunctionDeclaration.from_callable(callable=isolar_vocais, client=gemini)
fn_isolar_guitarra = types.FunctionDeclaration.from_callable(callable=isolar_guitarra, client=gemini)
fn_isolar_baixo = types.FunctionDeclaration.from_callable(callable=isolar_baixo, client=gemini)
fn_isolar_bateria = types.FunctionDeclaration.from_callable(callable=isolar_bateria, client=gemini)
fn_isolar_piano = types.FunctionDeclaration.from_callable(callable=isolar_piano, client=gemini)
fn_remover_vocais = types.FunctionDeclaration.from_callable(callable=remover_vocais, client=gemini)
fn_abaixar_bateria = types.FunctionDeclaration.from_callable(callable=abaixar_bateria, client=gemini)
fn_aumentar_baixo = types.FunctionDeclaration.from_callable(callable=aumentar_baixo, client=gemini)
fn_resetar_mixagem = types.FunctionDeclaration.from_callable(callable=resetar_mixagem, client=gemini)
fn_mostrar_todos_instrumentos = types.FunctionDeclaration.from_callable(callable=mostrar_todos_instrumentos, client=gemini)
fn_metronomo_ligado = types.FunctionDeclaration.from_callable(callable=metronomo_ligado, client=gemini)
fn_metronomo_desligado = types.FunctionDeclaration.from_callable(callable=metronomo_desligado, client=gemini)
fn_definir_metronomo_por_bpm = types.FunctionDeclaration.from_callable(callable=definir_metronomo_por_bpm, client=gemini)
fn_contar_entrada = types.FunctionDeclaration.from_callable(callable=contar_entrada, client=gemini)
fn_gravar_tomada = types.FunctionDeclaration.from_callable(callable=gravar_tomada, client=gemini)
fn_parar_gravacao = types.FunctionDeclaration.from_callable(callable=parar_gravacao, client=gemini)
fn_comparar_tomadas = types.FunctionDeclaration.from_callable(callable=comparar_tomadas, client=gemini)
fn_transpor_para_cima = types.FunctionDeclaration.from_callable(callable=transpor_para_cima, client=gemini)
fn_transpor_para_baixo = types.FunctionDeclaration.from_callable(callable=transpor_para_baixo, client=gemini)
fn_transpor_para_cima_um_passo_inteiro = types.FunctionDeclaration.from_callable(callable=transpor_para_cima_um_passo_inteiro, client=gemini)
fn_transpor_para_baixo_um_passo_inteiro = types.FunctionDeclaration.from_callable(callable=transpor_para_baixo_um_passo_inteiro, client=gemini)

# %%
moises_fns_gemini_pt = [
    fn_play,
    fn_pausar,
    fn_do_inicio,
    fn_voltar,
    fn_avancar,
    fn_diminuir_ritmo_muito,
    fn_metade_da_velocidade,
    fn_acelerar,
    fn_tocar,
    fn_diminuir_velocidade,
    fn_diminuir_muito,
    fn_velocidade_normal,
    fn_definir_tempo_por_porcentagem,
    fn_definir_tempo_por_bpm,
    fn_loopar_trecho,
    fn_ir_para_refrao,
    fn_ir_para_verso,
    fn_ir_para_solo,
    fn_loopar_refrao,
    fn_loopar_verso,
    fn_loopar_solo,
    fn_limpar_loop,
    fn_isolar_vocais,
    fn_isolar_guitarra,
    fn_isolar_baixo,
    fn_isolar_bateria,
    fn_isolar_piano,
    fn_remover_vocais,
    fn_abaixar_bateria,
    fn_aumentar_baixo,
    fn_resetar_mixagem,
    fn_mostrar_todos_instrumentos,
    fn_metronomo_ligado,
    fn_metronomo_desligado,
    fn_definir_metronomo_por_bpm,
    fn_contar_entrada,
    fn_gravar_tomada,
    fn_parar_gravacao,
    fn_comparar_tomadas,
    fn_transpor_para_cima,
    fn_transpor_para_baixo,
    fn_transpor_para_cima_um_passo_inteiro,
    fn_transpor_para_baixo_um_passo_inteiro,
]

# %% [markdown]
# ## setup

# %%
# model setup
config_en = types.GenerateContentConfig(
    tools=[types.Tool(function_declarations=moises_fns_gemini_en)]
  )

config_pt = types.GenerateContentConfig(
    tools=[types.Tool(function_declarations=moises_fns_gemini_pt)]
  )

chat_en = gemini.chats.create(model='gemini-2.0-flash', config=config_en)
chat_pt = gemini.chats.create(model='gemini-2.0-flash', config=config_pt)

# %% [markdown]
# ### test

# %%
# basic test
gemini_hello_answer = chat_pt.send_message('oi')

for block in gemini_hello_answer.candidates[0].content.parts:
    if block.function_call:
        print(block.function_call)
    else:
        print(block.text)
# [block.function_call if block.function_call else block.text for block in gemini_hello_answer.candidates[0].content.parts]
# Out:
# Olá! Como posso ajudar?

# %% [markdown]
# ## invoke

# %%
# invoke gemini
# @retry(stop=stop_after_attempt(10), wait=wait_exponential(multiplier=1, min=4, max=10))
def invoke_gemini(text, lang):
    iteration_timing = None
    start_timing = time.time()
    gemini_response = chat_en.send_message(text) if lang == 'en' else chat_pt.send_message(text)
    end_timing = time.time()
    iteration_timing = end_timing - start_timing
    url = r'C:\Users\julio\Desktop\dev\artificial-intelligence\projects\function_calling\assets\data\processed\model_prompt\gemini\gemini_response_pt.txt'
    with open(url, 'a') as file:
        file.write(f"\ndata: {time.strftime('%Y-%m-%d %H:%M:%S', time.localtime())}\n")
        file.write(f"prompt: {text}\n")
        print('START----')
        try:
            functions = []
            for block in gemini_response.candidates[0].content.parts:
                if block.function_call:
                    function = block.function_call
                    file.write(f"function: {function}\n")
                    file.write("-----------------------------------")
                    print(f"gemini fn: {function}")
                    functions.append(function.name)
                else:
                    text = block.text
                    file.write(f"text: {text}\n")
                    file.write("-----------------------------------")
                    print(f"gemini say: {text}")
            print('EXIT----')
            return functions, iteration_timing
        except TypeError as e:
            file.write(f"TypeError: {e}\n")
            file.write("-----------------------------------")
            return [], iteration_timing
        except Exception as e:
            file.write(f"Unexpected error: {e}\n")
            file.write("-----------------------------------")
            return [], iteration_timing

# %% [markdown]
# ### test

# %%
invoke_gemini('iniciar minha festa!', 'en')
# Out:
# START----
# gemini fn: id=None args={} name='play'
# EXIT----
# (['play'], 0.6713621616363525)

# %%
invoke_gemini('iniciar minha festa!', 'pt')
# Out:
# START----
# gemini say: Com prazer! O que você gostaria de tocar primeiro?
# EXIT----
# ([], 0.7507975101470947)

# %% [markdown]
# # CODE PT

# %% [markdown]
# ## eazy

# %%
cmd_en_openai = [invoke_openai('quero escutar a musica, vc pode dar um play?!', 'en'), 
                 invoke_openai('quero escutar a musica, vc pode dar um play?!', 'pt')]

cmd_en_openai
# Out:
# START----
# openai fn: Function(arguments='{}', name='play')
# EXIT----
# START----
# openai fn: Function(arguments='{}', name='reproduzir')
# EXIT----
# [(['play'], 1.3443348407745361), (['reproduzir'], 0.6551845073699951)]

# %%
cmd_en_claude = [invoke_claude('quero escutar a musica, vc pode dar um play?!', 'en'), 
                 invoke_claude('quero escutar a musica, vc pode dar um play?!', 'pt')]

cmd_en_claude
# Out:
# START----
# claude say: Vou iniciar a reprodução da música para você.
# claude fn: ToolUseBlock(id='toolu_01EvydwRHVPEuwm2NdfPDUau', input={}, name='play', type='tool_use')
# EXIT----
# START----
# claude say: Claro, vou iniciar a reprodução da música para você agora mesmo.
# claude fn: ToolUseBlock(id='toolu_01PG48P1mNwYZCpfYTbfASFf', input={}, name='reproduzir', type='tool_use')
# EXIT----
# [(['play'], 1.5060691833496094), (['reproduzir'], 2.33980131149292)]

# %%
cmd_en_gemini = [invoke_gemini('quero escutar a musica, vc pode dar um play?!', 'en'), 
                 invoke_gemini('quero escutar a musica, vc pode dar um play?!', 'pt')]

cmd_en_gemini
# Out:
# START----
# gemini fn: id=None args={} name='play'
# EXIT----
# START----
# gemini fn: id=None args={} name='tocar'
# EXIT----
# [(['play'], 1.4887480735778809), (['tocar'], 0.6626393795013428)]

# %%
import pandas as pd

code_pt_df = pd.DataFrame({
    'openai': cmd_en_openai,
    'claude': cmd_en_claude,
    'gemini': cmd_en_gemini,
})

code_pt_df
# Out:
#                                openai                            claude  \
# 0        ([play], 1.3443348407745361)      ([play], 1.5060691833496094)
# 1  ([reproduzir], 0.6551845073699951)  ([reproduzir], 2.33980131149292)
#
#                           gemini
# 0   ([play], 1.4887480735778809)
# 1  ([tocar], 0.6626393795013428)

# %% [markdown]
# ## medium

# %%
cmd_en_openai = [invoke_openai('tem como isolar o som do piano, e da guitarra?!', 'en'), 
                 invoke_openai('tem como isolar o som do piano, e da guitarra?!', 'pt')]

cmd_en_openai
# Out:
# START----
# openai fn: Function(arguments='{"stemType": "piano"}', name='isolate_piano')
# openai fn: Function(arguments='{"stemType": "guitar"}', name='isolate_guitar')
# EXIT----
# START----
# openai fn: Function(arguments='{"tipo_de_stem": "piano"}', name='isolar_piano')
# openai fn: Function(arguments='{"tipo_de_stem": "guitarra"}', name='isolar_guitarra')
# EXIT----
# [(['isolate_piano', 'isolate_guitar'], 1.7088050842285156),
#  (['isolar_piano', 'isolar_guitarra'], 1.06803560256958)]

# %%
cmd_en_claude = [invoke_claude('tem como isolar o som do piano, e da guitarra?!', 'en'), 
                 invoke_claude('tem como isolar o som do piano, e da guitarra?!', 'pt')]

cmd_en_claude
# Out:
# START----
# claude say: Você gostaria de isolar o som do piano e da guitarra. Posso fazer isso através das funções disponíveis para separação de instrumentos.
#
# Vou isolar o piano primeiro:
# claude fn: ToolUseBlock(id='toolu_01NJuekXkT6sSSYrTs7Jevrf', input={'stemType': 'piano'}, name='isolate_piano', type='tool_use')
# EXIT----
# START----
# claude say: Sim, posso isolar o som do piano e da guitarra para você! Vou ajudá-lo com esses comandos.
#
# Para isolar o piano:
# claude fn: ToolUseBlock(id='toolu_01EShxmgmDKej7oRyzAygJtQ', input={'tipo_de_stem': 'piano'}, name='isolar_piano', type='tool_use')
# EXIT----
# [(['isolate_piano'], 2.932065010070801),
#  (['isolar_piano'], 3.2422096729278564)]

# %%
cmd_en_gemini = [invoke_gemini('tem como isolar o som do piano, e da guitarra?!', 'en'), 
                 invoke_gemini('tem como isolar o som do piano, e da guitarra?!', 'pt')]

cmd_en_gemini
# Out:
# START----
# gemini fn: id=None args={'stemType': 'piano'} name='isolate_piano'
# gemini fn: id=None args={'stemType': 'guitar'} name='isolate_guitar'
# EXIT----
# START----
# gemini say: Você gostaria de isolar o piano ou a guitarra primeiro?
# EXIT----
# [(['isolate_piano', 'isolate_guitar'], 1.606208086013794),
#  ([], 1.432159662246704)]

# %%
code_pt_df_2 = pd.DataFrame({
    'openai': cmd_en_openai,
    'claude': cmd_en_claude,
    'gemini': cmd_en_gemini,
})

code_pt_df_2
# Out:
#                                               openai  \
# 0  ([isolate_piano, isolate_guitar], 1.7088050842...
# 1  ([isolar_piano, isolar_guitarra], 1.0680356025...
#
#                                  claude  \
# 0  ([isolate_piano], 2.932065010070801)
# 1  ([isolar_piano], 3.2422096729278564)
#
#                                               gemini
# 0  ([isolate_piano, isolate_guitar], 1.6062080860...
# 1                            ([], 1.432159662246704)

# %% [markdown]
# ## hard

# %%
cmd_en_openai = [invoke_openai('toca ai, e direto para o refrão!', 'en'), 
                 invoke_openai('toca ai, e direto para o refrão!', 'pt')]

cmd_en_openai
# Out:
# START----
# openai fn: Function(arguments='{}', name='play')
# openai fn: Function(arguments='{"sectionName": "chorus"}', name='go_to_chorus')
# EXIT----
# START----
# openai fn: Function(arguments='{}', name='reproduzir')
# openai fn: Function(arguments='{"nomeSecao": "refrão"}', name='ir_para_refrao')
# EXIT----
# [(['play', 'go_to_chorus'], 1.683689832687378),
#  (['reproduzir', 'ir_para_refrao'], 0.9017348289489746)]

# %%
cmd_en_claude = [invoke_claude('toca ai, e direto para o refrão!', 'en'), 
                 invoke_claude('toca ai, e direto para o refrão!', 'pt')]

cmd_en_claude
# Out:
# START----
# claude say: Vou tocar a música e ir direto para o refrão.
# claude fn: ToolUseBlock(id='toolu_01YMrNjdcds72aBHoErpL3xt', input={}, name='play', type='tool_use')
# EXIT----
# START----
# claude say: Vou iniciar a reprodução e pular para o refrão de imediato.
# claude fn: ToolUseBlock(id='toolu_01RQotay93XjFMnnmn7zu3Vo', input={}, name='reproduzir', type='tool_use')
# EXIT----
# [(['play'], 2.334481954574585), (['reproduzir'], 2.434803009033203)]

# %%
cmd_en_gemini = [invoke_gemini('toca ai, e direto para o refrão!', 'en'), 
                 invoke_gemini('toca ai, e direto para o refrão!', 'pt')]

cmd_en_gemini
# Out:
# START----
# gemini fn: id=None args={} name='play'
# gemini fn: id=None args={'sectionName': 'chorus'} name='go_to_chorus'
# EXIT----
# START----
# gemini say: Para qual seção devo ir, refrão, verso ou solo?
# EXIT----
# [(['play', 'go_to_chorus'], 1.8051104545593262), ([], 0.756965160369873)]

# %%
code_pt_df_3 = pd.DataFrame({
    'openai': cmd_en_openai,
    'claude': cmd_en_claude,
    'gemini': cmd_en_gemini,
})

code_pt_df_3
# Out:
#                                               openai  \
# 0          ([play, go_to_chorus], 1.683689832687378)
# 1  ([reproduzir, ir_para_refrao], 0.9017348289489...
#
#                               claude  \
# 0        ([play], 2.334481954574585)
# 1  ([reproduzir], 2.434803009033203)
#
#                                        gemini
# 0  ([play, go_to_chorus], 1.8051104545593262)
# 1                     ([], 0.756965160369873)

# %% [markdown]
# ## save

# %%
code_pt_df.to_json(r'C:\Users\julio\Desktop\dev\artificial-intelligence\projects\function_calling\assets\data\proc_pt\plot_1\code_pt.json', index=False)

# %%
code_pt_df_2.to_json(r'C:\Users\julio\Desktop\dev\artificial-intelligence\projects\function_calling\assets\data\proc_pt\plot_1\code_pt_2.json', index=False)

# %%
code_pt_df_3.to_json(r'C:\Users\julio\Desktop\dev\artificial-intelligence\projects\function_calling\assets\data\proc_pt\plot_1\code_pt_3.json', index=False)
